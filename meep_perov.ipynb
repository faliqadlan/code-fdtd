# %% [markdown]
# <a href="https://colab.research.google.com/github/faliqadlan/code-fdtd/blob/main/meep_perov.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #init conda and meep

# %%
# run first and once

# !pip install -U https://github.com/conda-incubator/condacolab/archive/cuda-version-12.tar.gz
# !pip install -q condacolab
import condacolab
condacolab.install()
# Out:
# Collecting https://github.com/conda-incubator/condacolab/archive/cuda-version-12.tar.gz
#   Using cached https://github.com/conda-incubator/condacolab/archive/cuda-version-12.tar.gz
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ✨🍰✨ Everything looks OK!

# %%
# check condalab

import condacolab
condacolab.check()
# Out:
# ✨🍰✨ Everything looks OK!

# %%
# install meep

# !mamba install -c conda-forge pymeep pymeep-extras
# Out:
#                   __    __    __    __
#                  /  \  /  \  /  \  /  \
#                 /    \/    \/    \/    \
# ███████████████/  /██/  /██/  /██/  /████████████████████████
#               /  / \   / \   / \   / \  \____
#              /  /   \_/   \_/   \_/   \    o \__,
#             / _/                       \_____/  `
#             |/
#         ███╗   ███╗ █████╗ ███╗   ███╗██████╗  █████╗
#         ████╗ ████║██╔══██╗████╗ ████║██╔══██╗██╔══██╗
#         ██╔████╔██║███████║██╔████╔██║██████╔╝███████║
#         ██║╚██╔╝██║██╔══██║██║╚██╔╝██║██╔══██╗██╔══██║
#         ██║ ╚═╝ ██║██║  ██║██║ ╚═╝ ██║██████╔╝██║  ██║
#         ╚═╝     ╚═╝╚═╝  ╚═╝╚═╝     ╚═╝╚═════╝ ╚═╝  ╚═╝
#
#         mamba (1.4.1) supported by @QuantStack
#
#         GitHub:  https://github.com/mamba-org/mamba
#         Twitter: https://twitter.com/QuantStack
#
# █████████████████████████████████████████████████████████████
#
#
# Looking for: ['pymeep', 'pymeep-extras']
#
# conda-forge/linux-64                                        Using cache
# conda-forge/noarch                                          Using cache
#
# Pinned packages:
#   - python 3.10.*
#   - python 3.10.*
#   - python_abi 3.10.* *cp310*
#   - cuda-version 12.*
#
#
# Transaction
#
#   Prefix: /usr/local
#
#   All requested packages already installed

# %%
# check version meep

import meep as mp
mp.__version__
# Out:
# '1.29.0'

# %%
# install other

# !pip install nlopt
# !pip install matplotlib
# !pip install numpy
# !pip install pandas
# Out:
# Requirement already satisfied: nlopt in /usr/local/lib/python3.10/site-packages (2.7.1)
# Requirement already satisfied: numpy>=1.14 in /usr/local/lib/python3.10/site-packages (from nlopt) (1.26.4)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/site-packages (3.8.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/site-packages (from matplotlib) (2.9.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: numpy<2,>=1.21 in /usr/local/lib/python3.10/site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/site-packages (from matplotlib) (10.0.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/site-packages (from matplotlib) (4.53.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/site-packages (from matplotlib) (24.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/site-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/site-packages (1.26.4)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/site-packages (2.2.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/site-packages (from pandas) (2.9.0)
# Requirement already satisfied: numpy>=1.22.4 in /usr/local/lib/python3.10/site-packages (from pandas) (1.26.4)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/site-packages (from pandas) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %% [markdown]
# # import n k

# %%
import pandas as pd
from google.colab import drive

# This will prompt for authorization.
drive.mount('/content/drive')

# After executing the cell above, Drive
# files will be present in "/content/drive/My Drive".
# If the file is in a folder, the path will look like:
# '/content/drive/My Drive/folder/your_file.csv'

dataNK = pd.read_csv('/content/drive/My Drive/n_k data.csv')
dataNK
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#      Wavelength (nm)  Air_n  Air_k  Spiro_n  Spiro_k   TiO2_n   TiO2_k  \
# 0                301      1      0  1.61701  0.25452  2.67767  0.62089
# 1                302      1      0  1.62022  0.25795  2.68572  0.60651
# 2                303      1      0  1.62360  0.26089  2.69355  0.59251
# 3                304      1      0  1.62709  0.26335  2.70112  0.57898
# 4                305      1      0  1.63072  0.26535  2.70854  0.56568
# ..               ...    ...    ...      ...      ...      ...      ...
# 594              895      1      0  1.67604  0.00379  2.04614  0.00000
# 595              896      1      0  1.67627  0.00428  2.04601  0.00000
# 596              897      1      0  1.67650  0.00482  2.04587  0.00000
# 597              898      1      0  1.67673  0.00542  2.04574  0.00000
# 598              899      1      0  1.67695  0.00608  2.04561  0.00000
#
#      SodaLime_n  SodaLime_k  Perov_n  ...  FTema_n  FTema_k  FAema_n  FAema_k  \
# 0       1.54873    0.000059  1.48952  ...  2.27183  0.16484  1.74080  0.02115
# 1       1.54837    0.000056  1.48478  ...  2.26866  0.16262  1.73865  0.02030
# 2       1.54800    0.000053  1.48040  ...  2.26555  0.16046  1.73658  0.01951
# 3       1.54764    0.000051  1.47642  ...  2.26253  0.15839  1.73453  0.01878
# 4       1.54727    0.000048  1.47298  ...  2.25949  0.15632  1.73256  0.01807
# ..          ...         ...      ...  ...      ...      ...      ...      ...
# 594     1.50200    0.000004  2.42143  ...  1.77954  0.01303  1.43703  0.01240
# 595     1.50193    0.000004  2.42093  ...  1.77886  0.01308  1.43659  0.01245
# 596     1.50190    0.000004  2.42042  ...  1.77823  0.01312  1.43612  0.01249
# 597     1.50190    0.000004  2.41993  ...  1.77761  0.01317  1.43572  0.01253
# 598     1.50190    0.000004  2.41942  ...  1.77698  0.01322  1.43527  0.01258
#
#      TPema_n  TPema_k  SpiroTFSI4Ox_n  SpiroTFSI4Ox_k  SpOxema_n  SpOxema_k
# 0    2.24501  0.70247         1.64180        0.251950       1.62    0.25400
# 1    2.24828  0.69505         1.64526        0.254320       1.62    0.25800
# 2    2.25154  0.68812         1.64898        0.256190       1.63    0.26000
# 3    2.25478  0.68169         1.65279        0.257480       1.63    0.26300
# 4    2.25814  0.67567         1.65663        0.258730       1.63    0.26500
# ..       ...      ...             ...             ...        ...        ...
# 594  2.17520  0.04419         1.67284        0.000561       1.68    0.00347
# 595  2.17494  0.04410         1.67237        0.000537       1.68    0.00391
# 596  2.17467  0.04400         1.67246        0.000606       1.68    0.00440
# 597  2.17442  0.04391         1.67331        0.000338       1.68    0.00491
# 598  2.17416  0.04382         1.67286        0.000299       1.68    0.00550
#
# [599 rows x 31 columns]

# %%
print(dataNK.columns)
# Out:
# Index(['Wavelength (nm)', 'Air_n', 'Air_k', 'Spiro_n', 'Spiro_k', 'TiO2_n',
#        'TiO2_k', 'SodaLime_n', 'SodaLime_k', 'Perov_n', 'Perov_k',
#        'PerovPtPt_n', 'PerovPtPt_k', 'Au_n', 'Au_k', 'SnO2_n', 'SnO2_k',
#        'SiO2_n', 'SiO2_k', 'FTO_n', 'FTO_k', 'FTema_n', 'FTema_k', 'FAema_n',
#        'FAema_k', 'TPema_n', 'TPema_k', 'SpiroTFSI4Ox_n', 'SpiroTFSI4Ox_k',
#        'SpOxema_n', 'SpOxema_k'],
#       dtype='object')

# %% [markdown]
# # init data

# %%
import meep as mp
import numpy as np
from typing import List

# set data for wavelengt and n k materials
wavelengths = dataNK["Wavelength (nm)"]
wavelengthsUm = [i / 1000 for i in wavelengths]
freqs = [1000 / (i) for i in wavelengths]
auN = dataNK["Au_n"]
auK = dataNK["Au_k"]
spiroN = dataNK["Spiro_n"]
spiroK = dataNK["Spiro_k"]
perovN = dataNK["Perov_n"]
perovK = dataNK["Perov_k"]
tio2N = dataNK["TiO2_n"]
tio2K = dataNK["TiO2_k"]

# Define the dimensions of the simulation
# 1um = 1000 nm
auHeight = 0.1  # 0.1 um or 100 nm
spiroHeight = 0.2  # 0.2 um or 200 nm
perovHeight = 0.37  # 0.37 um or 370 nm
tio2Height = 0.07  # 0.07 um or 70 nm
xLength = 1  # 1 um or 1000 nm
yLength = 1  # 1 um or 1000 nm
cellHeight = auHeight + spiroHeight + perovHeight + tio2Height
cellLength = 1
cellWidth = 1
cellSim = mp.Vector3(16, 8 + 0.5)
nmtoum = 1000

# %%
"""
A module for fitting the complex refractive index profile over a broad
bandwidth to a sum of Lorentzian polarizability terms using gradient-based
optimization via NLopt (nlopt.readthedocs.io). The fitting parameters are
then used to define a `Medium` object.
"""

from typing import Tuple
import csv
import matplotlib
import meep as mp
import nlopt
import numpy as np
import matplotlib.pyplot as plt

def lorentzfunc(p: np.ndarray, x: np.ndarray) -> np.ndarray:
    """
    Returns the complex ε profile given a set of Lorentzian parameters p
    (σ_0, ω_0, γ_0, σ_1, ω_1, γ_1, ...) for a set of frequencies x.
    """
    N = len(p) // 3
    y = np.zeros(len(x))
    for n in range(N):
        A_n = p[3 * n + 0]
        x_n = p[3 * n + 1]
        g_n = p[3 * n + 2]
        y = y + A_n / (np.square(x_n) - np.square(x) - 1j * x * g_n)
    return y


def lorentzerr(p: np.ndarray, x: np.ndarray, y: np.ndarray, grad: np.ndarray) -> float:
    """
    Returns the error (or residual or loss) as the L2 norm
    of the difference of ε(p,x) and y over a set of frequencies x as
    well as the gradient of this error with respect to each Lorentzian
    polarizability parameter in p and saving the result in grad.
    """
    N = len(p) // 3
    yp = lorentzfunc(p, x)
    val = np.sum(np.square(abs(y - yp)))
    for n in range(N):
        A_n = p[3 * n + 0]
        x_n = p[3 * n + 1]
        g_n = p[3 * n + 2]
        d = 1 / (np.square(x_n) - np.square(x) - 1j * x * g_n)
        if grad.size > 0:
            grad[3 * n + 0] = 2 * np.real(np.dot(np.conj(yp - y), d))
            grad[3 * n + 1] = (
                -4 * x_n * A_n * np.real(np.dot(np.conj(yp - y), np.square(d)))
            )
            grad[3 * n + 2] = (
                -2 * A_n * np.imag(np.dot(np.conj(yp - y), x * np.square(d)))
            )
    return val


def lorentzfit(
    p0: np.ndarray,
    x: np.ndarray,
    y: np.ndarray,
    alg=nlopt.LD_LBFGS,
    tol: float = 1e-25,
    maxeval: float = 10000,
) -> Tuple[np.ndarray, float]:
    """
    Returns the optimal Lorentzian polarizability parameters and error
    which minimize the error in ε(p0,x) relative to y for an initial
    set of Lorentzian polarizability parameters p0 over a set of
    frequencies x using the NLopt algorithm alg for a relative
    tolerance tol and a maximum number of iterations maxeval.
    """
    opt = nlopt.opt(alg, len(p0))
    opt.set_ftol_rel(tol)
    opt.set_maxeval(maxeval)
    opt.set_lower_bounds(np.zeros(len(p0)))
    opt.set_upper_bounds(float("inf") * np.ones(len(p0)))
    opt.set_min_objective(lambda p, grad: lorentzerr(p, x, y, grad))
    local_opt = nlopt.opt(nlopt.LD_LBFGS, len(p0))
    local_opt.set_ftol_rel(1e-10)
    local_opt.set_xtol_rel(1e-8)
    opt.set_local_optimizer(local_opt)
    popt = opt.optimize(p0)
    minf = opt.last_optimum_value()
    return popt, minf

# Import the complex refractive index profile from a CSV file.
# The file format is three comma-separated columns:
#     wavelength (nm), real(n), imag(n).
# Fitting parameter: number of Lorentzian terms to use in the fit
# Number of times to repeat local optimization with random initial values.
def fit_material_properties(wavelength, nArray, kArray, num_lorentzians, num_repeat, fileNameDest):
    mydata = np.column_stack((wavelength, nArray, kArray))
    n = mydata[:, 1] + 1j * mydata[:, 2]

    # Fitting parameter: the instantaneous (infinite frequency) dielectric.
    # Should be > 1.0 for stability and chosen such that
    # np.amin(np.real(eps)) is ~1.0. eps is defined below.
    eps_inf = 1.1
    eps = np.square(n) - eps_inf

    wl = mydata[:, 0]
    # wl_min = 399
    # wl_max = 701
    # start_idx = np.where(wl > wl_min)[0][0]
    # end_idx = np.where(wl < wl_max)[0][-1] + 1

    # The fitting function is ε(f) where f is the frequency, rather than ε(λ).
    # Note: an equally spaced grid of wavelengths results in the larger
    #       wavelengths having a finer frequency grid than smaller ones.
    #       This feature may impact the accuracy of the fit.
    freqs = 1000 / wl
    freqs_reduced = freqs
    eps_reduced = eps

    # Fitting parameter: number of Lorentzian terms to use in the fit
    num_lorentzians = num_lorentzians

    # Number of times to repeat local optimization with random initial values.
    num_repeat = num_repeat

    ps = np.zeros((num_repeat, 3 * num_lorentzians))
    mins = np.zeros(num_repeat)
    for m in range(num_repeat):
        # Initial values for the Lorentzian polarizability terms. Each term
        # consists of three parameters (σ, ω, γ) and is chosen randomly.
        # Note: for the case of no absorption, γ should be set to zero.
        p_rand = [10 ** (np.random.random()) for _ in range(3 * num_lorentzians)]
        ps[m, :], mins[m] = lorentzfit(
            p_rand, freqs_reduced, eps_reduced, nlopt.LD_MMA, 1e-25, 50000
        )
        ps_str = "( " + ", ".join(f"{prm:.4f}" for prm in ps[m, :]) + " )"
        print(f"iteration:, {m:3d}, ps_str, {mins[m]:.6f}")

    # Find the best performing set of parameters.
    idx_opt = np.where(np.min(mins) == mins)[0][0]
    popt_str = "( " + ", ".join(f"{prm:.4f}" for prm in ps[idx_opt]) + " )"
    print(f"optimal:, {popt_str}, {mins[idx_opt]:.6f}")

    # Define a `Medium` class object using the optimal fitting parameters.
    E_susceptibilities = []
    fileNameDest = fileNameDest + ".csv"
    with open(fileNameDest, mode='w', newline='') as file:
      writer = csv.writer(file)
      # Write the header row
      writer.writerow(['mymaterial_freq', 'mymaterial_gamma', 'mymaterial_sigma'])

      for n in range(num_lorentzians):
        mymaterial_freq = ps[idx_opt][3 * n + 1]
        mymaterial_gamma = ps[idx_opt][3 * n + 2]

        if mymaterial_freq == 0:
            mymaterial_sigma = ps[idx_opt][3 * n + 0]
            E_susceptibilities.append(
                mp.DrudeSusceptibility(
                    frequency=1.0, gamma=mymaterial_gamma, sigma=mymaterial_sigma
                )
            )
        else:
            mymaterial_sigma = ps[idx_opt][3 * n + 0] / mymaterial_freq**2
            E_susceptibilities.append(
                mp.LorentzianSusceptibility(
                    frequency=mymaterial_freq,
                    gamma=mymaterial_gamma,
                    sigma=mymaterial_sigma,
                )
            )
        # Write the values to the CSV file
        writer.writerow([mymaterial_freq, mymaterial_gamma, mymaterial_sigma])

    return E_susceptibilities

# func to plot epsilon actual
def plotEps(wavelength, nArray, kArray, epsInf):
    eps = [complex(nArray[i], kArray[i]) ** 2 for i in range(len(kArray))]
    eps = [e - epsInf for e in eps]
    plt.scatter(wavelength, [i.real for i in eps], label="Real", s=0.5)
    plt.scatter(wavelength, [i.imag for i in eps], label="Imaginary", s=0.5)
    plt.xlabel("Wavelength (nm)")
    plt.ylabel("Epsilon")
    plt.legend()
    plt.show()

# func to plot comparasion epsilon actual with fit
def plotEpsComp(wavelength, nArray, kArray, epsReal, epsImag):
    eps = [complex(nArray[i], kArray[i]) ** 2 for i in range(len(kArray))]
    plt.scatter(wavelength, [i.real for i in eps], label="Real actual", s=0.5)
    plt.scatter(wavelength, epsReal, label="Real fit", s=0.5)
    plt.scatter(wavelength, [i.imag for i in eps], label="Imaginary actual", s=0.5)
    plt.scatter(wavelength, epsImag, label="Imaginary fit", s=0.5)
    plt.xlabel("Wavelength (nm)")
    plt.ylabel("Epsilon")
    plt.legend()
    plt.show()

# %%
eps_inf = 1.1
plotEps(wavelengths, perovN, perovK, eps_inf)

# %% [markdown]
# # susceptibilities perov

# %%
# perovEscp = fit_material_properties(wavelengths, perovN, perovK, 10, 25, "perovEscp")

# # print(perovEscp)
# perovMat = mp.Medium(epsilon=eps_inf, E_susceptibilities=perovEscp)
# pervMatEps = [perovMat.epsilon(f)[0][0] for f in freqs]

# # print(pervMatEps)
# plotEpsComp(wavelengths, perovN, perovK, np.real(pervMatEps), np.imag(pervMatEps))

# %%
import csv
import meep as mp

def read_material_parameters_from_csv(filename='material_parameters.csv'):
    E_susceptibilities = []

    with open(filename, mode='r', newline='') as file:
        reader = csv.reader(file)
        next(reader)  # Skip the header row

        for row in reader:
            mymaterial_freq = float(row[0])
            mymaterial_gamma = float(row[1])
            mymaterial_sigma = float(row[2])

            if mymaterial_freq == 0:
                susceptibility = mp.DrudeSusceptibility(
                    frequency=1.0, gamma=mymaterial_gamma, sigma=mymaterial_sigma
                )
            else:
                susceptibility = mp.LorentzianSusceptibility(
                    frequency=mymaterial_freq,
                    gamma=mymaterial_gamma,
                    sigma=mymaterial_sigma,
                )
            E_susceptibilities.append(susceptibility)

    return E_susceptibilities

# %%
perovEscp = read_material_parameters_from_csv("/content/drive/MyDrive/perovEscp.csv")
perovMat = mp.Medium(epsilon=eps_inf, E_susceptibilities=perovEscp)
pervMatEps = [perovMat.epsilon(f)[0][0] for f in freqs]
plotEpsComp(wavelengths, perovN, perovK, np.real(pervMatEps), np.imag(pervMatEps))

# %% [markdown]
# # test simulation E_suscepbility

# %%
import numpy as np
import math
import matplotlib.pyplot as plt


resolution = 200  # pixels/μm

dpml = 1.0
sz = 10 + 2 * dpml
cell_size = mp.Vector3(z=sz)
pml_layers = [mp.PML(dpml)]

wvl_min = 0.4
wvl_max = 0.8
fmin = 1 / wvl_max
fmax = 1 / wvl_min
fcen = 0.5 * (fmax + fmin)
df = fmax - fmin
nfreq = 50

sources = [
    mp.Source(
        mp.GaussianSource(fcen, fwidth=df),
        component=mp.Ex,
        center=mp.Vector3(z=-0.5 * sz + dpml),
    )
]

sim = mp.Simulation(
    cell_size=cell_size,
    boundary_layers=pml_layers,
    sources=sources,
    dimensions=1,
    resolution=resolution,
)

refl_fr = mp.FluxRegion(center=mp.Vector3(z=-0.25 * sz))
refl = sim.add_flux(fcen, df, nfreq, refl_fr)

sim.run(until_after_sources=mp.stop_when_fields_decayed(50, mp.Ex, mp.Vector3(), 1e-9))

empty_flux = mp.get_fluxes(refl)
empty_data = sim.get_flux_data(refl)
sim.reset_meep()

geometry = [
    mp.Block(
        mp.Vector3(mp.inf, mp.inf, 0.5 * sz),
        center=mp.Vector3(z=0.25 * sz),
        material=perovMat,
    )
]

sim = mp.Simulation(
    cell_size=cell_size,
    boundary_layers=pml_layers,
    geometry=geometry,
    sources=sources,
    dimensions=1,
    resolution=resolution,
)

refl = sim.add_flux(fcen, df, nfreq, refl_fr)
sim.load_minus_flux_data(refl, empty_data)

sim.run(until_after_sources=mp.stop_when_fields_decayed(50, mp.Ex, mp.Vector3(), 1e-9))

refl_flux = mp.get_fluxes(refl)
R_meep = -1 * np.divide(refl_flux, empty_flux)
# Out:
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000481129 s
# Working in 1D dimensions.
# Computational cell is 0 x 0 x 12 with resolution 200
# time for set_epsilon = 0.00143719 s
# -----------
# field decay(t = 50.0025): 0.2501893277392139 / 0.2501893277392139 = 1.0
# on time step 39603 (time=99.0075), 0.000101004 s/step
# field decay(t = 100.0025): 4.3583172700896866e-16 / 0.2501893277392139 = 1.7420076665430753e-15
# run 0 finished at t = 100.0025 (40001 timesteps)
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000444174 s
# Working in 1D dimensions.
# Computational cell is 0 x 0 x 12 with resolution 200
#      block, center = (0,0,3)
#           size (1e+20,1e+20,6)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1.1,1.1,1.1)
# time for set_epsilon = 0.00187397 s
# lorentzian susceptibility: frequency=7.15914, gamma=0
# lorentzian susceptibility: frequency=10.0191, gamma=0
# lorentzian susceptibility: frequency=1.39999, gamma=0.179627
# lorentzian susceptibility: frequency=7.10024, gamma=0
# lorentzian susceptibility: frequency=1.94846, gamma=0.718302
# lorentzian susceptibility: frequency=2.36232, gamma=0.923318
# lorentzian susceptibility: frequency=2.79026, gamma=0.756699
# lorentzian susceptibility: frequency=3.45581, gamma=0.649787
# lorentzian susceptibility: frequency=7.17562, gamma=0
# lorentzian susceptibility: frequency=10.0133, gamma=0
# -----------
# on time step 11762 (time=29.405), 0.000340089 s/step
# field decay(t = 50.0025): 0.07851492518083046 / 0.07851492518083046 = 1.0
# on time step 27945 (time=69.8625), 0.000247321 s/step
# field decay(t = 100.0025): 2.779997642078871e-16 / 0.07851492518083046 = 3.540725073196162e-15
# run 0 finished at t = 100.0025 (40001 timesteps)

# %%
print(R_meep)
# Out:
# [0.18628312 0.18874548 0.19126473 0.19358025 0.19511021 0.19498578
#  0.1928743  0.19004032 0.1882901  0.18818555 0.18930687 0.19112319
#  0.19328539 0.19560094 0.19796608 0.20031979 0.20261972 0.20482976
#  0.20691386 0.20883335 0.21054669 0.21201043 0.21318136 0.21402043
#  0.21449728 0.2145949  0.21431427 0.21367756 0.21272848 0.21152996
#  0.21015907 0.20869929 0.20723218 0.20583002 0.20455039 0.2034329
#  0.20249998 0.20175915 0.20120689 0.20083343 0.20062753 0.20057986
#  0.20068564 0.20094636 0.20136882 0.20196448 0.20274642 0.20372627
#  0.2049137  0.20630876]

# %%
freqs = mp.get_flux_freqs(refl)
wvls = np.divide(1, freqs)

plt.figure()
plt.plot(wvls, R_meep, "bo-", label="meep")
plt.xlabel("wavelength (μm)")
plt.ylabel("reflectance")
plt.legend(loc="upper right")
plt.show()

# %% [markdown]
# # try bend flux

# %%
import numpy as np
import matplotlib.pyplot as plt

import meep as mp
from meep.materials import SiO2

resolution = 100  # pixels/um

dpml = 1.0
pml_layers = [mp.PML(thickness=dpml)]

r = 1.0  # radius of cylinder
dair = 2.0  # air padding thickness

s = 2 * (dpml + dair + r)
cell_size = mp.Vector3(s, s)

wvl_min = 0.4
wvl_max = 0.8
fmin = 1 / wvl_max
fmax = 1 / wvl_min
fcen = 0.5 * (fmax + fmin) # pulse center frequency
df = fmax - fmin # pulse width (in frequency)
nfreq = int((fcen + df/2) - (fcen - df/2))
nfreq = 100
print("fcen", fcen)
print("df", df)
print("nfreq", nfreq)

# is_integrated=True necessary for any planewave source extending into PML
sources = [
    mp.Source(
        mp.GaussianSource(fcen, fwidth=df, is_integrated=False),
        center=mp.Vector3(-0.5 * s + dpml),
        size=mp.Vector3(0, 1, 0),
        component=mp.Ez,
    )
]

sim = mp.Simulation(
    cell_size=cell_size,
    boundary_layers=pml_layers,
    sources=sources,
    resolution=resolution,
)

refl_fr = mp.FluxRegion(
    center=mp.Vector3(-2.5), size=mp.Vector3(0, 1.5)
)


refl = sim.add_flux(fcen, df, nfreq, refl_fr)
print("refl pos", refl_fr.center)
print("refl size", refl_fr.size)

tran_fr = mp.FluxRegion(
    center=mp.Vector3(3), size=mp.Vector3(0, 1.5)
)
tran = sim.add_flux(fcen, df, nfreq, tran_fr)
print("tran pos", tran_fr.center)
print("tran size", tran_fr.size)

plt.figure(dpi=150)
sim.plot2D()
plt.show()
# Out:
# fcen 1.875
# df 1.25
# nfreq 100
# refl pos Vector3<-2.5, 0.0, 0.0>
# refl size Vector3<0.0, 1.5, 0.0>
# tran pos Vector3<3.0, 0.0, 0.0>
# tran size Vector3<0.0, 1.5, 0.0>

# %%
sim.run(until_after_sources=mp.stop_when_fields_decayed(5, mp.Ez, mp.Vector3(0,0), 1e-3))
# Out:
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.00107408 s
# Working in 2D dimensions.
# Computational cell is 8 x 8 x 0 with resolution 100
# time for set_epsilon = 1.60422 s
# -----------
# on time step 591 (time=2.955), 0.00677731 s/step
# field decay(t = 5.005): 0.00012037939422327533 / 0.00012037939422327533 = 1.0
# on time step 1218 (time=6.09), 0.006382 s/step
# on time step 1773 (time=8.865), 0.00722037 s/step
# field decay(t = 10.01): 0.1524021144364923 / 0.1524021144364923 = 1.0
# on time step 2303 (time=11.515), 0.00755737 s/step
# on time step 2933 (time=14.665), 0.00635907 s/step
# field decay(t = 15.015): 8.13966919046148e-08 / 0.1524021144364923 = 5.340916181220946e-07
# run 0 finished at t = 15.015 (3003 timesteps)

# %%
empty_flux = mp.get_fluxes(refl)
empty_data = sim.get_flux_data(refl)
sim.reset_meep()
# Out:
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.00111103 s
# Working in 2D dimensions.
# Computational cell is 8 x 8 x 0 with resolution 100
# time for set_epsilon = 0.915781 s
# -----------

# %%
geometry = [mp.Block(material=perovMat, center=mp.Vector3(), size=mp.Vector3(8,1))]

sim = mp.Simulation(
    resolution=resolution,
    cell_size=cell_size,
    boundary_layers=pml_layers,
    sources=sources,
    geometry=geometry,
)

refl = sim.add_flux(fcen, df, nfreq, refl_fr)

tran = sim.add_flux(fcen, df, nfreq, tran_fr)

plt.figure(dpi=150)
sim.plot2D()
plt.show()
# Out:
#      block, center = (0,0,0)
#           size (8,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1.1,1.1,1.1)

# %%
sim.load_minus_flux_data(refl, empty_data)

sim.run(until_after_sources=mp.stop_when_fields_decayed(50, mp.Ez, mp.Vector3(), 1e-3))

straight_refl_data = sim.get_flux_data(refl)
# Out:
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.00103807 s
# Working in 2D dimensions.
# Computational cell is 8 x 8 x 0 with resolution 100
#      block, center = (0,0,0)
#           size (8,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1.1,1.1,1.1)
# time for set_epsilon = 1.08592 s
# lorentzian susceptibility: frequency=7.15914, gamma=0
# lorentzian susceptibility: frequency=10.0191, gamma=0
# lorentzian susceptibility: frequency=1.39999, gamma=0.179627
# lorentzian susceptibility: frequency=7.10024, gamma=0
# lorentzian susceptibility: frequency=1.94846, gamma=0.718302
# lorentzian susceptibility: frequency=2.36232, gamma=0.923318
# lorentzian susceptibility: frequency=2.79026, gamma=0.756699
# lorentzian susceptibility: frequency=3.45581, gamma=0.649787
# lorentzian susceptibility: frequency=7.17562, gamma=0
# lorentzian susceptibility: frequency=10.0133, gamma=0
# -----------
# on time step 101 (time=0.505), 0.0397207 s/step
# on time step 232 (time=1.16), 0.0307042 s/step
# on time step 367 (time=1.835), 0.0296887 s/step
# on time step 493 (time=2.465), 0.0317577 s/step
# on time step 607 (time=3.035), 0.0352964 s/step
# on time step 743 (time=3.715), 0.029533 s/step
# on time step 878 (time=4.39), 0.0297083 s/step
# on time step 997 (time=4.985), 0.0336606 s/step
# on time step 1121 (time=5.605), 0.0323635 s/step
# on time step 1257 (time=6.285), 0.0295246 s/step
# on time step 1392 (time=6.96), 0.0298755 s/step
# on time step 1505 (time=7.525), 0.0355616 s/step
# on time step 1639 (time=8.195), 0.02995 s/step
# on time step 1775 (time=8.875), 0.0294126 s/step
# on time step 1889 (time=9.445), 0.035189 s/step
# on time step 2007 (time=10.035), 0.0340707 s/step
# on time step 2143 (time=10.715), 0.0294225 s/step
# on time step 2280 (time=11.4), 0.0293057 s/step
# on time step 2398 (time=11.99), 0.0339372 s/step
# on time step 2527 (time=12.635), 0.0310731 s/step
# on time step 2664 (time=13.32), 0.0292499 s/step
# on time step 2795 (time=13.975), 0.0305662 s/step
# on time step 2909 (time=14.545), 0.0351651 s/step
# on time step 3045 (time=15.225), 0.0296075 s/step
# on time step 3181 (time=15.905), 0.0294337 s/step
# on time step 3302 (time=16.51), 0.0332807 s/step
# on time step 3426 (time=17.13), 0.0324633 s/step
# on time step 3563 (time=17.815), 0.0292829 s/step
# on time step 3700 (time=18.5), 0.0292624 s/step
# on time step 3813 (time=19.065), 0.0357271 s/step
# on time step 3947 (time=19.735), 0.0299912 s/step
# on time step 4083 (time=20.415), 0.0294692 s/step
# on time step 4195 (time=20.975), 0.0358297 s/step
# on time step 4313 (time=21.565), 0.0340421 s/step
# on time step 4450 (time=22.25), 0.0292176 s/step
# on time step 4587 (time=22.935), 0.0292671 s/step
# on time step 4704 (time=23.52), 0.0343367 s/step
# on time step 4831 (time=24.155), 0.0315955 s/step
# on time step 4967 (time=24.835), 0.0294527 s/step
# on time step 5100 (time=25.5), 0.0303096 s/step
# on time step 5213 (time=26.065), 0.0355761 s/step
# on time step 5348 (time=26.74), 0.0297831 s/step
# on time step 5483 (time=27.415), 0.0298053 s/step
# on time step 5603 (time=28.015), 0.0334129 s/step
# on time step 5722 (time=28.61), 0.0336805 s/step
# on time step 5857 (time=29.285), 0.029732 s/step
# on time step 5992 (time=29.96), 0.0297714 s/step
# on time step 6105 (time=30.525), 0.0354906 s/step
# on time step 6237 (time=31.185), 0.0303332 s/step
# on time step 6374 (time=31.87), 0.0293928 s/step
# on time step 6500 (time=32.5), 0.0318408 s/step
# on time step 6617 (time=33.085), 0.0342898 s/step
# on time step 6747 (time=33.735), 0.0309683 s/step
# on time step 6882 (time=34.41), 0.0298345 s/step
# on time step 6996 (time=34.98), 0.0352794 s/step
# on time step 7122 (time=35.61), 0.0319054 s/step
# on time step 7257 (time=36.285), 0.0297131 s/step
# on time step 7385 (time=36.925), 0.0314027 s/step
# on time step 7497 (time=37.485), 0.0358008 s/step
# on time step 7631 (time=38.155), 0.0299762 s/step
# on time step 7765 (time=38.825), 0.0298597 s/step
# on time step 7880 (time=39.4), 0.0350559 s/step
# on time step 8001 (time=40.005), 0.0330767 s/step
# on time step 8132 (time=40.66), 0.0305788 s/step
# on time step 8266 (time=41.33), 0.0298914 s/step
# on time step 8376 (time=41.88), 0.0365788 s/step
# on time step 8501 (time=42.505), 0.0320314 s/step
# on time step 8625 (time=43.125), 0.0323994 s/step
# on time step 8747 (time=43.735), 0.0329192 s/step
# on time step 8847 (time=44.235), 0.0400258 s/step
# on time step 8962 (time=44.81), 0.0349822 s/step
# on time step 9091 (time=45.455), 0.0311514 s/step
# on time step 9202 (time=46.01), 0.0361791 s/step
# on time step 9310 (time=46.55), 0.0372845 s/step
# on time step 9431 (time=47.155), 0.0332861 s/step
# on time step 9551 (time=47.755), 0.0335908 s/step
# on time step 9653 (time=48.265), 0.0394577 s/step
# on time step 9774 (time=48.87), 0.033136 s/step
# on time step 9904 (time=49.52), 0.030961 s/step
# field decay(t = 50.005): 8.790521543034824e-11 / 8.790521543034824e-11 = 1.0
# on time step 10024 (time=50.12), 0.0336358 s/step
# on time step 10133 (time=50.665), 0.0367703 s/step
# on time step 10262 (time=51.31), 0.031023 s/step
# on time step 10391 (time=51.955), 0.0310134 s/step
# on time step 10493 (time=52.465), 0.0392605 s/step
# on time step 10607 (time=53.035), 0.0351765 s/step
# on time step 10737 (time=53.685), 0.0309083 s/step
# on time step 10866 (time=54.33), 0.0310483 s/step
# on time step 10977 (time=54.885), 0.0363361 s/step
# on time step 11104 (time=55.52), 0.0317329 s/step
# on time step 11234 (time=56.17), 0.030836 s/step
# on time step 11358 (time=56.79), 0.0323157 s/step
# on time step 11472 (time=57.36), 0.035293 s/step
# on time step 11604 (time=58.02), 0.0304926 s/step
# on time step 11736 (time=58.68), 0.0305467 s/step
# on time step 11852 (time=59.26), 0.0346987 s/step
# on time step 11975 (time=59.875), 0.0326445 s/step
# on time step 12108 (time=60.54), 0.0301704 s/step
# on time step 12240 (time=61.2), 0.0303956 s/step
# on time step 12350 (time=61.75), 0.0366788 s/step
# on time step 12472 (time=62.36), 0.0328005 s/step
# on time step 12606 (time=63.03), 0.0298867 s/step
# on time step 12729 (time=63.645), 0.0326627 s/step
# on time step 12843 (time=64.215), 0.0352723 s/step
# on time step 12975 (time=64.875), 0.0304643 s/step
# on time step 13096 (time=65.48), 0.0332988 s/step
# on time step 13203 (time=66.015), 0.0376535 s/step
# on time step 13327 (time=66.635), 0.0324069 s/step
# on time step 13455 (time=67.275), 0.0314969 s/step
# on time step 13584 (time=67.92), 0.0310756 s/step
# on time step 13694 (time=68.47), 0.0363958 s/step
# on time step 13825 (time=69.125), 0.0307032 s/step
# on time step 13954 (time=69.77), 0.0311335 s/step
# on time step 14072 (time=70.36), 0.0340537 s/step
# on time step 14192 (time=70.96), 0.0335211 s/step
# on time step 14321 (time=71.605), 0.0311303 s/step
# on time step 14449 (time=72.245), 0.0313813 s/step
# on time step 14562 (time=72.81), 0.0355578 s/step
# on time step 14694 (time=73.47), 0.0304056 s/step
# on time step 14829 (time=74.145), 0.0297106 s/step
# on time step 14951 (time=74.755), 0.0329607 s/step
# on time step 15070 (time=75.35), 0.0336591 s/step
# on time step 15203 (time=76.015), 0.0301503 s/step
# on time step 15339 (time=76.695), 0.0294775 s/step
# on time step 15453 (time=77.265), 0.0350917 s/step
# on time step 15580 (time=77.9), 0.0316902 s/step
# on time step 15709 (time=78.545), 0.0311634 s/step
# on time step 15840 (time=79.2), 0.0305679 s/step
# on time step 15948 (time=79.74), 0.0371735 s/step
# on time step 16081 (time=80.405), 0.0302472 s/step
# on time step 16215 (time=81.075), 0.0299003 s/step
# on time step 16333 (time=81.665), 0.0341264 s/step
# on time step 16455 (time=82.275), 0.0329319 s/step
# on time step 16586 (time=82.93), 0.0306209 s/step
# on time step 16722 (time=83.61), 0.0294785 s/step
# on time step 16825 (time=84.125), 0.0389821 s/step
# on time step 16955 (time=84.775), 0.0309931 s/step
# on time step 17087 (time=85.435), 0.0303351 s/step
# on time step 17212 (time=86.06), 0.0320159 s/step
# on time step 17328 (time=86.64), 0.0344863 s/step
# on time step 17459 (time=87.295), 0.0307051 s/step
# on time step 17587 (time=87.935), 0.0313448 s/step
# on time step 17695 (time=88.475), 0.037124 s/step
# on time step 17809 (time=89.045), 0.0351693 s/step
# on time step 17937 (time=89.685), 0.0313543 s/step
# on time step 18063 (time=90.315), 0.0319814 s/step
# on time step 18174 (time=90.87), 0.0361728 s/step
# on time step 18289 (time=91.445), 0.0349514 s/step
# on time step 18424 (time=92.12), 0.0296502 s/step
# on time step 18547 (time=92.735), 0.0326939 s/step
# on time step 18664 (time=93.32), 0.0343251 s/step
# on time step 18799 (time=93.995), 0.029756 s/step
# on time step 18934 (time=94.67), 0.0297593 s/step
# on time step 19050 (time=95.25), 0.0345098 s/step
# on time step 19165 (time=95.825), 0.034831 s/step
# on time step 19297 (time=96.485), 0.0304623 s/step
# on time step 19424 (time=97.12), 0.0315436 s/step
# on time step 19530 (time=97.65), 0.0380842 s/step
# on time step 19657 (time=98.285), 0.0317022 s/step
# on time step 19787 (time=98.935), 0.0307847 s/step
# on time step 19898 (time=99.49), 0.0363325 s/step
# field decay(t = 100.01): 3.0841553312310575e-16 / 8.790521543034824e-11 = 3.508500964513067e-06
# run 0 finished at t = 100.01 (20002 timesteps)

# %%
straight_tran_flux = mp.get_fluxes(tran)
print(straight_tran_flux)
# Out:
# [8.897344690642585e-11, 1.3144810056634677e-10, 1.9597475385174585e-10, 2.9290350819410333e-10, 4.3614834343173975e-10, 6.441661951931124e-10, 9.413824005700234e-10, 1.3604353005919985e-09, 1.9458456776976938e-09, 2.759701711186379e-09, 3.889148961520547e-09, 5.4537120663911716e-09, 7.60905061017211e-09, 1.0545209040918732e-08, 1.4482064764883924e-08, 1.9667498219663532e-08, 2.6380055710634272e-08, 3.493199585692709e-08, 4.566843806375346e-08, 5.8962975739850515e-08, 7.521332667355399e-08, 9.484019696834017e-08, 1.1829049089261139e-07, 1.460436903520613e-07, 1.786182403211872e-07, 2.1657315438783507e-07, 2.605000091230654e-07, 3.1100199861417455e-07, 3.6865985244803386e-07, 4.339877458833032e-07, 5.073846207495233e-07, 5.890871646547255e-07, 6.791297992473848e-07, 7.773153723529718e-07, 8.831981588464269e-07, 9.960791308852267e-07, 1.1150121431470416e-06, 1.2388190229389382e-06, 1.3661114832691028e-06, 1.495318159031042e-06, 1.6247154828011531e-06, 1.7524618851559645e-06, 1.8766349742416695e-06, 1.995271586325745e-06, 2.10641035708857e-06, 2.208136307830183e-06, 2.298626279427563e-06, 2.3761942323620516e-06, 2.4393350579207304e-06, 2.4867656760894074e-06, 2.5174622431850513e-06, 2.5306925369311948e-06, 2.526042493788407e-06, 2.5034359338954466e-06, 2.463146431070929e-06, 2.405800420456692e-06, 2.3323702639625044e-06, 2.244156418481864e-06, 2.1427581297809467e-06, 2.0300326409374396e-06, 1.9080435428682867e-06, 1.7789997750734854e-06, 1.6451877055451075e-06, 1.508899448338651e-06, 1.3723611577645633e-06, 1.2376651183916834e-06, 1.106709596484969e-06, 9.811496503709601e-07, 8.623612818583197e-07, 7.514203166882364e-07, 6.490962382519164e-07, 5.558601281176566e-07, 4.719047912449939e-07, 3.971746207026457e-07, 3.3140227502784617e-07, 2.7414928654682844e-07, 2.248477298096224e-07, 1.8284049364098207e-07, 1.4741832300054955e-07, 1.1785225589884722e-07, 9.342064368348611e-08, 7.343043949328844e-08, 5.7232917725556085e-08, 4.423424457536841e-08, 3.390151817993355e-08, 2.576503150195146e-08, 1.941757121806249e-08, 1.4511505999475881e-08, 1.0754331104174368e-08, 7.903277954685133e-09, 5.759486847094934e-09, 4.162110113262782e-09, 2.9826231158052546e-09, 2.119539105480708e-09, 1.4936443965813024e-09, 1.0438146350047023e-09, 7.234048906617711e-10, 4.972040073520809e-10, 3.3892261192768145e-10, 2.2913923957456136e-10]

# %%
sim.reset_meep()

geometry = [
    mp.Block(
        material=perovMat,
        center=mp.Vector3(-1.5),
        size=mp.Vector3(5,1)
    ),
    mp.Block(
        material=perovMat,
        center=mp.Vector3(0.5,1.75),
        size=mp.Vector3(1,3)
    ),
]

sim = mp.Simulation(
    resolution=resolution,
    cell_size=cell_size,
    boundary_layers=pml_layers,
    sources=sources,
    geometry=geometry,
)

# reflected flux
refl = sim.add_flux(fcen, df, nfreq, refl_fr)

tran_fr = mp.FluxRegion(
    center=mp.Vector3(0.5,3,0), size=mp.Vector3(1.5)
)
tran = sim.add_flux(fcen, df, nfreq, tran_fr)

# for normal run, load negated fields to subtract incident from refl. fields
sim.load_minus_flux_data(refl, straight_refl_data)

pt = mp.Vector3(0.5, 1.3)

sim.run(until_after_sources=mp.stop_when_fields_decayed(50, mp.Ez, pt, 1e-7))

bend_refl_flux = mp.get_fluxes(refl)
bend_tran_flux = mp.get_fluxes(tran)

flux_freqs = mp.get_flux_freqs(refl)

plt.figure(dpi=150)
sim.plot2D()
plt.show()
# Out:
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000983953 s
# Working in 2D dimensions.
# Computational cell is 8 x 8 x 0 with resolution 100
#      block, center = (-1.5,0,0)
#           size (5,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1.1,1.1,1.1)
#      block, center = (0.5,1.75,0)
#           size (1,3,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1.1,1.1,1.1)
# time for set_epsilon = 1.1196 s
# lorentzian susceptibility: frequency=7.15914, gamma=0
# lorentzian susceptibility: frequency=10.0191, gamma=0
# lorentzian susceptibility: frequency=1.39999, gamma=0.179627
# lorentzian susceptibility: frequency=7.10024, gamma=0
# lorentzian susceptibility: frequency=1.94846, gamma=0.718302
# lorentzian susceptibility: frequency=2.36232, gamma=0.923318
# lorentzian susceptibility: frequency=2.79026, gamma=0.756699
# lorentzian susceptibility: frequency=3.45581, gamma=0.649787
# lorentzian susceptibility: frequency=7.17562, gamma=0
# lorentzian susceptibility: frequency=10.0133, gamma=0
# -----------
# on time step 129 (time=0.645), 0.0311667 s/step
# on time step 245 (time=1.225), 0.034523 s/step
# on time step 367 (time=1.835), 0.0329803 s/step
# on time step 500 (time=2.5), 0.0301615 s/step
# on time step 632 (time=3.16), 0.0305079 s/step
# on time step 741 (time=3.705), 0.0367159 s/step
# on time step 873 (time=4.365), 0.0303761 s/step
# on time step 1005 (time=5.025), 0.0303344 s/step
# on time step 1128 (time=5.64), 0.0327495 s/step
# on time step 1244 (time=6.22), 0.0346848 s/step
# on time step 1377 (time=6.885), 0.0301906 s/step
# on time step 1507 (time=7.535), 0.0308062 s/step
# on time step 1619 (time=8.095), 0.0358187 s/step
# on time step 1745 (time=8.725), 0.0319399 s/step
# on time step 1878 (time=9.39), 0.0300973 s/step
# on time step 2002 (time=10.01), 0.0324211 s/step
# on time step 2116 (time=10.58), 0.0352557 s/step
# on time step 2249 (time=11.245), 0.0301715 s/step
# on time step 2375 (time=11.875), 0.0317835 s/step
# on time step 2492 (time=12.46), 0.034368 s/step
# on time step 2611 (time=13.055), 0.0336238 s/step
# on time step 2743 (time=13.715), 0.0304382 s/step
# on time step 2872 (time=14.36), 0.0310879 s/step
# on time step 2981 (time=14.905), 0.036903 s/step
# on time step 3110 (time=15.55), 0.0310429 s/step
# on time step 3242 (time=16.21), 0.0304098 s/step
# on time step 3356 (time=16.78), 0.0354093 s/step
# on time step 3471 (time=17.355), 0.0348911 s/step
# on time step 3598 (time=17.99), 0.0315787 s/step
# on time step 3728 (time=18.64), 0.0309082 s/step
# on time step 3840 (time=19.2), 0.0357569 s/step
# on time step 3964 (time=19.82), 0.032466 s/step
# on time step 4099 (time=20.495), 0.0298345 s/step
# on time step 4227 (time=21.135), 0.0314949 s/step
# on time step 4338 (time=21.69), 0.0362071 s/step
# on time step 4469 (time=22.345), 0.0305778 s/step
# on time step 4601 (time=23.005), 0.0305002 s/step
# on time step 4718 (time=23.59), 0.0342725 s/step
# on time step 4836 (time=24.18), 0.0340707 s/step
# on time step 4964 (time=24.82), 0.0314827 s/step
# on time step 5092 (time=25.46), 0.0313091 s/step
# on time step 5196 (time=25.98), 0.0384819 s/step
# on time step 5322 (time=26.61), 0.0317637 s/step
# on time step 5451 (time=27.255), 0.0310612 s/step
# on time step 5574 (time=27.87), 0.0325611 s/step
# on time step 5687 (time=28.435), 0.035416 s/step
# on time step 5817 (time=29.085), 0.0308697 s/step
# on time step 5950 (time=29.75), 0.030118 s/step
# on time step 6060 (time=30.3), 0.0364115 s/step
# on time step 6176 (time=30.88), 0.0347049 s/step
# on time step 6308 (time=31.54), 0.0303463 s/step
# on time step 6437 (time=32.185), 0.0310556 s/step
# on time step 6542 (time=32.71), 0.0383618 s/step
# on time step 6668 (time=33.34), 0.0319728 s/step
# on time step 6798 (time=33.99), 0.0309218 s/step
# on time step 6922 (time=34.61), 0.0324201 s/step
# on time step 7029 (time=35.145), 0.0376685 s/step
# on time step 7158 (time=35.79), 0.0312311 s/step
# on time step 7286 (time=36.43), 0.0314768 s/step
# on time step 7395 (time=36.975), 0.0367029 s/step
# on time step 7509 (time=37.545), 0.035316 s/step
# on time step 7639 (time=38.195), 0.0308385 s/step
# on time step 7769 (time=38.845), 0.0310612 s/step
# on time step 7881 (time=39.405), 0.035755 s/step
# on time step 8014 (time=40.07), 0.0302805 s/step
# on time step 8146 (time=40.73), 0.0304552 s/step
# on time step 8271 (time=41.355), 0.0320346 s/step
# on time step 8382 (time=41.91), 0.0362516 s/step
# on time step 8513 (time=42.565), 0.0306046 s/step
# on time step 8641 (time=43.205), 0.0313962 s/step
# on time step 8749 (time=43.745), 0.0374709 s/step
# on time step 8863 (time=44.315), 0.0352251 s/step
# on time step 8989 (time=44.945), 0.0318309 s/step
# on time step 9112 (time=45.56), 0.0328717 s/step
# on time step 9217 (time=46.085), 0.0382439 s/step
# on time step 9347 (time=46.735), 0.0307965 s/step
# on time step 9476 (time=47.38), 0.0311425 s/step
# on time step 9591 (time=47.955), 0.0348788 s/step
# on time step 9697 (time=48.485), 0.0377672 s/step
# on time step 9826 (time=49.13), 0.0311336 s/step
# on time step 9953 (time=49.765), 0.0315289 s/step
# field decay(t = 50.005): 1.888527944195286e-09 / 1.888527944195286e-09 = 1.0
# on time step 10057 (time=50.285), 0.0386295 s/step
# on time step 10177 (time=50.885), 0.0335309 s/step
# on time step 10306 (time=51.53), 0.0310311 s/step
# on time step 10429 (time=52.145), 0.032585 s/step
# on time step 10535 (time=52.675), 0.0377803 s/step
# on time step 10660 (time=53.3), 0.0322696 s/step
# on time step 10791 (time=53.955), 0.0305455 s/step
# on time step 10908 (time=54.54), 0.034355 s/step
# on time step 11024 (time=55.12), 0.0346609 s/step
# on time step 11156 (time=55.78), 0.0304107 s/step
# on time step 11287 (time=56.435), 0.0305349 s/step
# on time step 11399 (time=56.995), 0.0360082 s/step
# on time step 11526 (time=57.63), 0.0314974 s/step
# on time step 11658 (time=58.29), 0.0304229 s/step
# on time step 11782 (time=58.91), 0.0324663 s/step
# on time step 11894 (time=59.47), 0.0358285 s/step
# on time step 12026 (time=60.13), 0.0304593 s/step
# on time step 12157 (time=60.785), 0.0307809 s/step
# on time step 12271 (time=61.355), 0.0354162 s/step
# on time step 12386 (time=61.93), 0.0349286 s/step
# on time step 12513 (time=62.565), 0.0316757 s/step
# on time step 12642 (time=63.21), 0.031143 s/step
# on time step 12746 (time=63.73), 0.0385098 s/step
# on time step 12867 (time=64.335), 0.0331679 s/step
# on time step 12995 (time=64.975), 0.0314233 s/step
# on time step 13115 (time=65.575), 0.0335771 s/step
# on time step 13224 (time=66.12), 0.0367232 s/step
# on time step 13346 (time=66.73), 0.0329011 s/step
# on time step 13472 (time=67.36), 0.0319967 s/step
# on time step 13583 (time=67.915), 0.0362607 s/step
# on time step 13695 (time=68.475), 0.0357351 s/step
# on time step 13826 (time=69.13), 0.0306438 s/step
# on time step 13953 (time=69.765), 0.0317027 s/step
# on time step 14060 (time=70.3), 0.0376771 s/step
# on time step 14184 (time=70.92), 0.0323348 s/step
# on time step 14315 (time=71.575), 0.030698 s/step
# on time step 14435 (time=72.175), 0.0333644 s/step
# on time step 14544 (time=72.72), 0.0369251 s/step
# on time step 14672 (time=73.36), 0.0313447 s/step
# on time step 14804 (time=74.02), 0.0304974 s/step
# on time step 14918 (time=74.59), 0.0352007 s/step
# on time step 15041 (time=75.205), 0.0326612 s/step
# on time step 15172 (time=75.86), 0.0306027 s/step
# on time step 15299 (time=76.495), 0.0315608 s/step
# on time step 15406 (time=77.03), 0.0376387 s/step
# on time step 15535 (time=77.675), 0.0310156 s/step
# on time step 15665 (time=78.325), 0.0308646 s/step
# on time step 15786 (time=78.93), 0.0332181 s/step
# on time step 15899 (time=79.495), 0.0354419 s/step
# on time step 16027 (time=80.135), 0.0312856 s/step
# on time step 16159 (time=80.795), 0.0305375 s/step
# on time step 16271 (time=81.355), 0.0358591 s/step
# on time step 16389 (time=81.945), 0.0341296 s/step
# on time step 16518 (time=82.59), 0.0310952 s/step
# on time step 16643 (time=83.215), 0.0322946 s/step
# on time step 16749 (time=83.745), 0.0379731 s/step
# on time step 16874 (time=84.37), 0.032185 s/step
# on time step 16999 (time=84.995), 0.0321242 s/step
# on time step 17116 (time=85.58), 0.0342897 s/step
# on time step 17231 (time=86.155), 0.0350451 s/step
# on time step 17360 (time=86.8), 0.0312399 s/step
# on time step 17489 (time=87.445), 0.0311543 s/step
# on time step 17597 (time=87.985), 0.0370416 s/step
# on time step 17723 (time=88.615), 0.0318037 s/step
# on time step 17845 (time=89.225), 0.0328157 s/step
# on time step 17968 (time=89.84), 0.0327545 s/step
# on time step 18079 (time=90.395), 0.0361813 s/step
# on time step 18208 (time=91.04), 0.0312182 s/step
# on time step 18340 (time=91.7), 0.0304539 s/step
# on time step 18457 (time=92.285), 0.0342402 s/step
# on time step 18577 (time=92.885), 0.0334829 s/step
# on time step 18708 (time=93.54), 0.0306854 s/step
# on time step 18839 (time=94.195), 0.0306356 s/step
# on time step 18946 (time=94.73), 0.0376076 s/step
# on time step 19070 (time=95.35), 0.0324789 s/step
# on time step 19195 (time=95.975), 0.0322025 s/step
# on time step 19317 (time=96.585), 0.0330413 s/step
# on time step 19428 (time=97.14), 0.036066 s/step
# on time step 19559 (time=97.795), 0.030643 s/step
# on time step 19688 (time=98.44), 0.0311693 s/step
# on time step 19804 (time=99.02), 0.0346016 s/step
# on time step 19923 (time=99.615), 0.0336705 s/step
# field decay(t = 100.01): 5.612924850417236e-18 / 1.888527944195286e-09 = 2.9721163870884307e-09
# run 0 finished at t = 100.01 (20002 timesteps)
#      block, center = (-1.5,0,0)
#           size (5,1,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1.1,1.1,1.1)
#      block, center = (0.5,1.75,0)
#           size (1,3,0)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (1.1,1.1,1.1)

# %%
print(bend_refl_flux)
print(bend_tran_flux)
# Out:
# [8.456350783511941e-07, 1.2790972100709394e-06, 1.9189966845408335e-06, 2.855561102279402e-06, 4.214539312980992e-06, 6.169412868588576e-06, 8.957115229946516e-06, 1.2898025538954092e-05, 1.8421042853973403e-05, 2.6094554048081903e-05, 3.666408273305855e-05, 5.109729154765975e-05, 7.063676725593823e-05, 9.686065671055293e-05, 0.0001317507121778999, 0.0001777665688835518, 0.00023792409651710744, 0.00031587460241609623, 0.00041598079001359316, 0.0005433846814044987, 0.0007040617843384639, 0.0009048544800950687, 0.001153476437623763, 0.001458479196339314, 0.001829171634943169, 0.0022754830237175084, 0.0028077617607806505, 0.0034365050002576805, 0.004172018074511964, 0.005024005769202492, 0.006001099997933914, 0.007110330813791806, 0.008356551578113412, 0.009741837798829273, 0.011264894689321575, 0.012920525765490198, 0.01469922114437798, 0.016586909119743035, 0.01856488295048243, 0.020609888881500345, 0.02269436393244437, 0.024786842431947755, 0.02685257804971334, 0.028854415995293915, 0.030753892129679824, 0.032512469418912573, 0.03409279938486219, 0.03545993574184784, 0.0365824927848152, 0.03743377298998273, 0.037992856537100564, 0.03824557649728735, 0.0381852552627737, 0.03781308927991206, 0.03713813097320225, 0.03617688609334903, 0.03495258551565281, 0.03349419634359603, 0.03183523102921611, 0.030012415580804683, 0.028064292883090827, 0.026029849372066784, 0.023947247784887295, 0.02185272337264359, 0.01977966976634392, 0.017757917752871423, 0.01581320309511199, 0.013966821079195767, 0.012235467318401106, 0.010631259634303343, 0.009161925949670293, 0.007831132410664564, 0.006638919188859707, 0.0055822098376700135, 0.004655362273479401, 0.0038507327513990727, 0.003159227424629195, 0.0025708194216586128, 0.0020750135840805965, 0.0016612462036596086, 0.0013192126843570404, 0.0010391213891715293, 0.0008118765000272899, 0.000629196240256681, 0.0004836751228855897, 0.0003688000110354124, 0.00027892994862524506, 0.0002092492391988851, 0.0001557023389115941, 0.000114917945097901, 8.412832296876532e-05, 6.108854333589595e-05, 4.399902998973092e-05, 3.143371473552137e-05, 2.2275194597335315e-05, 1.5657572175305727e-05, 1.0917116796640045e-05, 7.550484958647786e-06, 5.179965263535279e-06, 3.5250451940439965e-06]
# [4.673049451583401e-10, 4.5215973237178614e-10, 4.1170769050415626e-10, 3.7386045632862195e-10, 3.952993698860271e-10, 5.646081208343215e-10, 9.958223560283493e-10, 1.8139227641646207e-09, 3.14380512901332e-09, 5.121947079459022e-09, 7.944563809166181e-09, 1.1946973365889878e-08, 1.7697826428425706e-08, 2.6103134634227144e-08, 3.8521593708362767e-08, 5.6862204405780215e-08, 8.359115505654316e-08, 1.2158656152791377e-07, 1.73876210102391e-07, 2.434040527123748e-07, 3.329964499833619e-07, 4.456170698211701e-07, 5.848837010180796e-07, 7.557343275089992e-07, 9.651001454233709e-07, 1.222440160715211e-06, 1.5400158043566644e-06, 1.9328133902337998e-06, 2.4180780324306503e-06, 3.014476339252021e-06, 3.7409627782188413e-06, 4.615456240275784e-06, 5.653446659248528e-06, 6.866652894434521e-06, 8.261849771477339e-06, 9.839983443235855e-06, 1.1595661007687725e-05, 1.351702944323723e-05, 1.5585972287687022e-05, 1.777846505494823e-05, 2.006493302048284e-05, 2.2410533154206084e-05, 2.4775415546247263e-05, 2.711514523395088e-05, 2.938149723062056e-05, 3.1523767602060456e-05, 3.349060317651629e-05, 3.523218263796876e-05, 3.670249597604361e-05, 3.786147049896912e-05, 3.867676651526998e-05, 3.912517543620845e-05, 3.9193618263867385e-05, 3.887974996305919e-05, 3.819216300941651e-05, 3.715013287971342e-05, 3.578285179561227e-05, 3.41281377893398e-05, 3.2230682658248765e-05, 3.0139966869484175e-05, 2.7908025363982593e-05, 2.5587252038636703e-05, 2.3228390433708837e-05, 2.087881371235068e-05, 1.8581140654161485e-05, 1.6372200071768687e-05, 1.4282331770840127e-05, 1.2335020182776275e-05, 1.0546849731468017e-05, 8.927766467530902e-06, 7.481616677090926e-06, 6.20690599119824e-06, 5.097703582197211e-06, 4.144611971509938e-06, 3.3357290664171615e-06, 2.6575457807893746e-06, 2.095740936582274e-06, 1.6358515485992194e-06, 1.2638093389394318e-06, 9.66345120439237e-07, 7.312699038317232e-07, 5.476460601641174e-07, 4.058652254635477e-07, 2.976508951707017e-07, 2.1600383396096016e-07, 1.5510737523122056e-07, 1.1020759214496612e-07, 7.748103637596771e-08, 5.3900020436677797e-08, 3.7102906877261106e-08, 2.527451948091719e-08, 1.7039717474605178e-08, 1.1371472091473984e-08, 7.513501175648896e-09, 4.91663596645661e-09, 3.187586458831201e-09, 2.0485251087447196e-09, 1.3058178405646017e-09, 8.262893109710383e-10, 5.195358329879627e-10]

# %%
wl = []
Rs = []
Ts = []
for i in range(nfreq):
    wl = np.append(wl, 1 / flux_freqs[i])
    Rs = np.append(Rs, bend_refl_flux[i] / straight_tran_flux[i])
    Ts = np.append(Ts, bend_tran_flux[i] / straight_tran_flux[i])

if mp.am_master():
    plt.figure(dpi=150)
    plt.plot(wl, Rs, "bo-", label="reflectance")
    plt.plot(wl, Ts, "ro-", label="transmittance")
    plt.plot(wl, 1 - Rs - Ts, "go-", label="loss")
    #plt.axis([5.0, 10.0, 0, 1])
    plt.xlabel("wavelength (μm)")
    plt.legend(loc="upper right")
    plt.show()
