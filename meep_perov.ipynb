# %% [markdown]
# <a href="https://colab.research.google.com/github/faliqadlan/code-fdtd/blob/main/meep_perov.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #init conda and meep

# %%
# run first and once

# !pip install -U https://github.com/conda-incubator/condacolab/archive/cuda-version-12.tar.gz
# !pip install -q condacolab
import condacolab
condacolab.install()
# Out:
# Collecting https://github.com/conda-incubator/condacolab/archive/cuda-version-12.tar.gz
#   Downloading https://github.com/conda-incubator/condacolab/archive/cuda-version-12.tar.gz
#      - 35.4 kB 6.1 MB/s 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Building wheels for collected packages: condacolab
#   Building wheel for condacolab (pyproject.toml) ... done
#   Created wheel for condacolab: filename=condacolab-0.1.7-py3-none-any.whl size=7213 sha256=9365a96b6520735412686587e713cff31b9edf8c9e2e6b46b08195c64532948c
#   Stored in directory: /root/.cache/pip/wheels/40/52/76/1ad2aa50f9ab880cfc0e418db37f474f468d2920eab048baa2
# Successfully built condacolab
# Installing collected packages: condacolab
# Successfully installed condacolab-0.1.7
# ⏬ Downloading https://github.com/conda-forge/miniforge/releases/download/23.1.0-1/Mambaforge-23.1.0-1-Linux-x86_64.sh...
# 📦 Installing...
# 📌 Adjusting configuration...
# 🩹 Patching environment...
# ⏲ Done in 0:00:16
# 🔁 Restarting kernel...

# %%
# check condalab

import condacolab
condacolab.check()
# Out:
# ✨🍰✨ Everything looks OK!

# %%
# install meep

# !mamba install -c conda-forge pymeep pymeep-extras
# Out:
#                   __    __    __    __
#                  /  \  /  \  /  \  /  \
#                 /    \/    \/    \/    \
# ███████████████/  /██/  /██/  /██/  /████████████████████████
#               /  / \   / \   / \   / \  \____
#              /  /   \_/   \_/   \_/   \    o \__,
#             / _/                       \_____/  `
#             |/
#         ███╗   ███╗ █████╗ ███╗   ███╗██████╗  █████╗
#         ████╗ ████║██╔══██╗████╗ ████║██╔══██╗██╔══██╗
#         ██╔████╔██║███████║██╔████╔██║██████╔╝███████║
#         ██║╚██╔╝██║██╔══██║██║╚██╔╝██║██╔══██╗██╔══██║
#         ██║ ╚═╝ ██║██║  ██║██║ ╚═╝ ██║██████╔╝██║  ██║
#         ╚═╝     ╚═╝╚═╝  ╚═╝╚═╝     ╚═╝╚═════╝ ╚═╝  ╚═╝
#
#         mamba (1.4.1) supported by @QuantStack
#
#         GitHub:  https://github.com/mamba-org/mamba
#         Twitter: https://twitter.com/QuantStack
#
# █████████████████████████████████████████████████████████████
#
#
# Looking for: ['pymeep', 'pymeep-extras']
#
# [+] 0.0s
# [+] 0.1s
# conda-forge/linux-64  ⣾
# conda-forge/noarch    ⣾  [+] 0.2s
# conda-forge/linux-64  ⣾
# conda-forge/noarch    ⣾  [+] 0.3s
# conda-forge/linux-64  ⣾
# conda-forge/noarch    ⣾  [+] 0.4s
# conda-forge/linux-64  ⣾
# conda-forge/noarch    ⣾  [+] 0.5s
# conda-forge/linux-64  ⣾
# conda-forge/noarch    ⣾  [+] 0.6s
# conda-forge/linux-64  ⣾
# conda-forge/noarch    ⣾  [+] 0.7s
# conda-forge/linux-64  ⣾
# conda-forge/noarch    ⣾  [+] 0.8s
# conda-forge/linux-64  ⣾
# conda-forge/noarch    ⣾  [+] 0.9s
# conda-forge/linux-64  ⣾
# conda-forge/noarch    ⣾  [+] 1.0s
# conda-forge/linux-64  ⣾
# conda-forge/noarch    ⣾  [+] 1.1s
# conda-forge/linux-64  ⣾
# conda-forge/noarch    ⣾  [+] 1.2s
# conda-forge/linux-64  ⣾
# conda-forge/noarch    ⣾  [+] 1.3s
# conda-forge/linux-64  ⣾
# conda-forge/noarch    ⣾  [+] 1.4s
# conda-forge/linux-64  ⣾
# conda-forge/noarch    ⣾  [+] 1.5s
# conda-forge/linux-64  ⣾
# conda-forge/noarch    ⣾  [+] 1.6s
# conda-forge/linux-64  ⣾
# conda-forge/noarch    ⣾  [+] 1.7s
# conda-forge/linux-64  ⣾
# conda-forge/noarch    ⣾  [+] 1.8s
# conda-forge/linux-64  ⣾
# conda-forge/noarch    ⣾  [+] 1.9s
# conda-forge/linux-64  ⣾
# conda-forge/noarch    ⣾  [+] 2.0s
# conda-forge/linux-64  ⣾
# conda-forge/noarch    ⣾  [+] 2.1s
# conda-forge/linux-64  ⣾
# conda-forge/noarch    ⣾  [+] 2.2s
# conda-forge/linux-64  ⣾
# conda-forge/noarch   100%[+] 2.3s
# conda-forge/linux-64  ⣾
# conda-forge/noarch   100%[+] 2.4s
# conda-forge/linux-64  ⣾  conda-forge/noarch
# [+] 2.5s
# conda-forge/linux-64  ⣾  [+] 2.6s
# conda-forge/linux-64  ⣾  [+] 2.7s
# conda-forge/linux-64  ⣾  [+] 2.8s
# conda-forge/linux-64  ⣾  [+] 2.9s
# conda-forge/linux-64  ⣾  [+] 3.0s
# conda-forge/linux-64  ⣾  [+] 3.1s
# conda-forge/linux-64  ⣾  [+] 3.2s
# conda-forge/linux-64  ⣾  [+] 3.3s
# conda-forge/linux-64  ⣾  [+] 3.4s
# conda-forge/linux-64  ⣾  [+] 3.5s
# conda-forge/linux-64  ⣾  [+] 3.6s
# conda-forge/linux-64  ⣾  [+] 3.7s
# conda-forge/linux-64  ⣾  [+] 3.8s
# conda-forge/linux-64  ⣾  [+] 3.9s
# conda-forge/linux-64  ⣾  [+] 4.0s
# conda-forge/linux-64  ⣾  [+] 4.1s
# conda-forge/linux-64  ⣾  [+] 4.2s
# conda-forge/linux-64  ⣾  [+] 4.3s
# conda-forge/linux-64  ⣾  [+] 4.4s
# conda-forge/linux-64  ⣾  [+] 4.5s
# conda-forge/linux-64  ⣾  [+] 4.6s
# conda-forge/linux-64  ⣾  [+] 4.7s
# conda-forge/linux-64  ⣾  [+] 4.8s
# conda-forge/linux-64  ⣾  [+] 4.9s
# conda-forge/linux-64 100%[+] 5.0s
# conda-forge/linux-64 100%[+] 5.1s
# conda-forge/linux-64 100%[+] 5.2s
# conda-forge/linux-64 100%[+] 5.3s
# conda-forge/linux-64 100%[+] 5.4s
# conda-forge/linux-64 100%[+] 5.5s
# conda-forge/linux-64 100%[+] 5.6s
# conda-forge/linux-64 100%[+] 5.7s
# conda-forge/linux-64 100%[+] 5.8s
# conda-forge/linux-64 100%[+] 5.9s
# conda-forge/linux-64
#
# Pinned packages:
#   - python 3.10.*
#   - python 3.10.*
#   - python_abi 3.10.* *cp310*
#   - cuda-version 12.*
#
#
# Transaction
#
#   Prefix: /usr/local
#
#   Updating specs:
#
#    - pymeep
#    - pymeep-extras
#    - ca-certificates
#    - certifi
#    - openssl
#
#
#   Package                         Version  Build                    Channel                    Size
# ─────────────────────────────────────────────────────────────────────────────────────────────────────
#   Install:
# ─────────────────────────────────────────────────────────────────────────────────────────────────────
#
#   + aom                             3.5.0  h27087fc_0               conda-forge/linux-64        3MB
#   + autograd                        1.6.2  pyhd8ed1ab_0             conda-forge/noarch         45kB
#   + brotli                          1.1.0  hd590300_1               conda-forge/linux-64       19kB
#   + brotli-bin                      1.1.0  hd590300_1               conda-forge/linux-64       19kB
#   + cached-property                 1.5.2  hd8ed1ab_1               conda-forge/noarch          4kB
#   + cached_property                 1.5.2  pyha770c72_1             conda-forge/noarch         11kB
#   + contourpy                       1.2.1  py310hd41b1e2_0          conda-forge/linux-64      242kB
#   + cycler                         0.12.1  pyhd8ed1ab_0             conda-forge/noarch         13kB
#   + expat                           2.6.2  h59595ed_0               conda-forge/linux-64      138kB
#   + ffmpeg                          5.1.2  gpl_h8dda1f0_106         conda-forge/linux-64       10MB
#   + fftw                           3.3.10  nompi_hf1063bd_110       conda-forge/linux-64        2MB
#   + font-ttf-dejavu-sans-mono        2.37  hab24e00_0               conda-forge/noarch        397kB
#   + font-ttf-inconsolata            3.000  h77eed37_0               conda-forge/noarch         97kB
#   + font-ttf-source-code-pro        2.038  h77eed37_0               conda-forge/noarch        701kB
#   + font-ttf-ubuntu                  0.83  h77eed37_2               conda-forge/noarch          2MB
#   + fontconfig                     2.14.2  h14ed4e7_0               conda-forge/linux-64      272kB
#   + fonts-conda-ecosystem               1  0                        conda-forge/noarch          4kB
#   + fonts-conda-forge                   1  0                        conda-forge/noarch          4kB
#   + fonttools                      4.53.1  py310h5b4e0ec_0          conda-forge/linux-64        2MB
#   + freetype                       2.12.1  h267a509_2               conda-forge/linux-64      635kB
#   + future                          1.0.0  pyhd8ed1ab_0             conda-forge/noarch        364kB
#   + gettext                        0.22.5  h59595ed_2               conda-forge/linux-64      475kB
#   + gettext-tools                  0.22.5  h59595ed_2               conda-forge/linux-64        3MB
#   + gmp                             6.3.0  hac33072_2               conda-forge/linux-64      460kB
#   + gnutls                          3.7.9  hb077bed_0               conda-forge/linux-64        2MB
#   + gsl                               2.7  he838d99_0               conda-forge/linux-64        3MB
#   + h5py                           3.10.0  nompi_py310ha2ad45a_100  conda-forge/linux-64        1MB
#   + h5utils                        1.13.2  nompi_ha1fc32c_1102      conda-forge/linux-64       70kB
#   + harminv                         1.4.2  hc567f7b_0               conda-forge/linux-64       45kB
#   + hdf5                           1.14.2  nompi_h4f84152_100       conda-forge/linux-64        4MB
#   + kiwisolver                      1.4.5  py310hd41b1e2_1          conda-forge/linux-64       73kB
#   + lame                            3.100  h166bdaf_1003            conda-forge/linux-64      508kB
#   + lcms2                            2.15  haa2dc70_1               conda-forge/linux-64      242kB
#   + lerc                            4.0.0  h27087fc_0               conda-forge/linux-64      282kB
#   + libaec                          1.1.3  h59595ed_0               conda-forge/linux-64       35kB
#   + libasprintf                    0.22.5  h661eb56_2               conda-forge/linux-64       43kB
#   + libasprintf-devel              0.22.5  h661eb56_2               conda-forge/linux-64       34kB
#   + libblas                         3.9.0  23_linux64_openblas      conda-forge/linux-64       15kB
#   + libbrotlicommon                 1.1.0  hd590300_1               conda-forge/linux-64       69kB
#   + libbrotlidec                    1.1.0  hd590300_1               conda-forge/linux-64       33kB
#   + libbrotlienc                    1.1.0  hd590300_1               conda-forge/linux-64      283kB
#   + libcblas                        3.9.0  23_linux64_openblas      conda-forge/linux-64       15kB
#   + libctl                          4.5.1  h7f98852_0               conda-forge/linux-64      117kB
#   + libdeflate                       1.18  h0b41bf4_0               conda-forge/linux-64       65kB
#   + libdrm                        2.4.122  h4ab18f5_0               conda-forge/linux-64      305kB
#   + libexpat                        2.6.2  h59595ed_0               conda-forge/linux-64       74kB
#   + libgdsii                         0.21  h4bd325d_4               conda-forge/linux-64       87kB
#   + libgettextpo                   0.22.5  h59595ed_2               conda-forge/linux-64      171kB
#   + libgettextpo-devel             0.22.5  h59595ed_2               conda-forge/linux-64       37kB
#   + libgfortran-ng                 13.2.0  h69a702a_0               conda-forge/linux-64       23kB
#   + libgfortran5                   13.2.0  ha4646dd_0               conda-forge/linux-64        1MB
#   + libidn2                         2.3.7  hd590300_0               conda-forge/linux-64      127kB
#   + libjpeg-turbo                 2.1.5.1  hd590300_1               conda-forge/linux-64      496kB
#   + liblapack                       3.9.0  23_linux64_openblas      conda-forge/linux-64       15kB
#   + libopenblas                    0.3.27  pthreads_hac2b453_1      conda-forge/linux-64        6MB
#   + libopus                         1.3.1  h7f98852_1               conda-forge/linux-64      261kB
#   + libpciaccess                     0.18  hd590300_0               conda-forge/linux-64       28kB
#   + libpng                         1.6.43  h2797004_0               conda-forge/linux-64      288kB
#   + libtasn1                       4.19.0  h166bdaf_0               conda-forge/linux-64      117kB
#   + libtiff                         4.5.1  h8b53f26_1               conda-forge/linux-64      417kB
#   + libunistring                   0.9.10  h7f98852_0               conda-forge/linux-64        1MB
#   + libva                          2.21.0  h4ab18f5_2               conda-forge/linux-64      190kB
#   + libvpx                         1.11.0  h9c3ff4c_3               conda-forge/linux-64        1MB
#   + libwebp-base                    1.4.0  hd590300_0               conda-forge/linux-64      439kB
#   + libxcb                           1.15  h0b41bf4_0               conda-forge/linux-64      384kB
#   + matplotlib-base                 3.8.0  py310h62c0568_1          conda-forge/linux-64        7MB
#   + mpb                            1.11.1  nompi_h2e71656_104       conda-forge/linux-64       68kB
#   + munkres                         1.1.4  pyh9f0ad1d_0             conda-forge/noarch         12kB
#   + nettle                          3.9.1  h7ab15ed_0               conda-forge/linux-64        1MB
#   + numpy                          1.26.4  py310hb13e2d6_0          conda-forge/linux-64        7MB
#   + openh264                        2.3.1  hcb278e6_2               conda-forge/linux-64      719kB
#   + openjpeg                        2.5.0  hfec8fc6_2               conda-forge/linux-64      352kB
#   + p11-kit                        0.24.1  hc5aa10d_0               conda-forge/linux-64        5MB
#   + packaging                        24.1  pyhd8ed1ab_0             conda-forge/noarch         50kB
#   + pillow                         10.0.0  py310h582fbeb_0          conda-forge/linux-64       47MB
#   + pthread-stubs                     0.4  h36c2ea0_1001            conda-forge/linux-64        6kB
#   + pymeep                         1.29.0  nompi_py310h1234567_103  conda-forge/linux-64        2MB
#   + pymeep-extras                  1.29.0  nompi_py310h82cca05_103  conda-forge/linux-64       14kB
#   + pyparsing                       3.1.2  pyhd8ed1ab_0             conda-forge/noarch         89kB
#   + python-dateutil                 2.9.0  pyhd8ed1ab_0             conda-forge/noarch        223kB
#   + scipy                          1.14.0  py310h93e2701_1          conda-forge/linux-64       17MB
#   + six                            1.16.0  pyh6c4a22f_0             conda-forge/noarch         14kB
#   + svt-av1                         1.4.1  hcb278e6_0               conda-forge/linux-64        2MB
#   + unicodedata2                   15.1.0  py310h2372a71_0          conda-forge/linux-64      374kB
#   + x264                       1!164.3095  h166bdaf_2               conda-forge/linux-64      898kB
#   + x265                              3.5  h924138e_3               conda-forge/linux-64        3MB
#   + xorg-fixesproto                   5.0  h7f98852_1002            conda-forge/linux-64        9kB
#   + xorg-kbproto                    1.0.7  h7f98852_1002            conda-forge/linux-64       27kB
#   + xorg-libx11                     1.8.9  h8ee46fc_0               conda-forge/linux-64      828kB
#   + xorg-libxau                    1.0.11  hd590300_0               conda-forge/linux-64       14kB
#   + xorg-libxdmcp                   1.1.3  h7f98852_0               conda-forge/linux-64       19kB
#   + xorg-libxext                    1.3.4  h0b41bf4_2               conda-forge/linux-64       50kB
#   + xorg-libxfixes                  5.0.3  h7f98852_1004            conda-forge/linux-64       18kB
#   + xorg-xextproto                  7.3.0  h0b41bf4_1003            conda-forge/linux-64       30kB
#   + xorg-xproto                    7.0.31  h7f98852_1007            conda-forge/linux-64       75kB
#   + zlib                           1.2.13  h166bdaf_4               conda-forge/linux-64       94kB
#
#   Change:
# ─────────────────────────────────────────────────────────────────────────────────────────────────────
#
#   - libmamba                        1.4.1  hcea66bb_0               conda-forge
#   + libmamba                        1.4.1  hcea66bb_0               conda-forge/linux-64     Cached
#
#   Upgrade:
# ─────────────────────────────────────────────────────────────────────────────────────────────────────
#
#   - ca-certificates             2022.12.7  ha878542_0               conda-forge
#   + ca-certificates              2024.7.4  hbcca054_0               conda-forge/linux-64      155kB
#   - certifi                     2022.12.7  pyhd8ed1ab_0             conda-forge
#   + certifi                      2024.7.4  pyhd8ed1ab_0             conda-forge/noarch        159kB
#   - krb5                           1.20.1  h81ceb04_0               conda-forge
#   + krb5                           1.21.3  h659f571_0               conda-forge/linux-64        1MB
#   - libcurl                        7.88.1  hdc1c0ab_1               conda-forge
#   + libcurl                         8.2.1  hca28451_0               conda-forge/linux-64      373kB
#   - libssh2                        1.10.0  hf14f497_3               conda-forge
#   + libssh2                        1.11.0  h0841786_0               conda-forge/linux-64      271kB
#   - openssl                         3.1.0  h0b41bf4_0               conda-forge
#   + openssl                         3.3.1  h4bc722e_2               conda-forge/linux-64        3MB
#
#   Summary:
#
#   Install: 96 packages
#   Change: 1 packages
#   Upgrade: 6 packages
#
#   Total download: 150MB
#
# ─────────────────────────────────────────────────────────────────────────────────────────────────────
#
#
# [+] 0.0s
# Downloading        0%
# Extracting         0%ca-certificates                                    154.9kB @   1.7MB/s  0.1s
# zlib                                                94.1kB @   1.0MB/s  0.1s
# [+] 0.1s
# Downloading  (5)   2%
# Extracting   (2)  ⣾  libctl                                             117.0kB @   1.0MB/s  0.1s
# svt-av1                                              2.5MB @  18.6MB/s  0.1s
# libpng                                             288.2kB @   2.1MB/s  0.0s
# libbrotlicommon                                     69.4kB @ 510.9kB/s  0.0s
# libtasn1                                           116.9kB @ 720.1kB/s  0.0s
# libvpx                                               1.1MB @   6.7MB/s  0.0s
# openh264                                           718.8kB @   4.2MB/s  0.0s
# x264                                               897.5kB @   5.1MB/s  0.0s
# libexpat                                            73.7kB @ 374.6kB/s  0.0s
# [+] 0.2s
# Downloading  (5)   6%
# Extracting  (10)  ⣾  pthread-stubs                                        5.6kB @  27.9kB/s  0.0s
# libgettextpo                                       170.6kB @ 837.3kB/s  0.0s
# xorg-libxdmcp                                       19.1kB @  92.0kB/s  0.0s
# aom                                                  2.9MB @  13.2MB/s  0.2s
# libbrotlienc                                       282.5kB @   1.3MB/s  0.0s
# xorg-fixesproto                                      9.1kB @  39.6kB/s  0.0s
# expat                                              137.6kB @ 585.7kB/s  0.0s
# lcms2                                              242.1kB @ 958.7kB/s  0.0s
# libblas                                             14.9kB @  57.1kB/s  0.0s
# libidn2                                            126.5kB @ 441.1kB/s  0.0s
# [+] 0.3s
# Downloading  (5)   8%
# Extracting  (21)  ⣾  libgettextpo-devel                                  36.8kB @ 108.2kB/s  0.1s
# libopenblas                                          5.6MB @  16.2MB/s  0.1s
# gettext                                            475.1kB @   1.4MB/s  0.1s
# gnutls                                               2.0MB @   5.6MB/s  0.1s
# hdf5                                                 3.7MB @  10.6MB/s  0.1s
# mpb                                                 68.5kB @ 179.5kB/s  0.0s
# contourpy                                          241.9kB @ 619.3kB/s  0.0s
# cycler                                              13.5kB @  34.4kB/s  0.0s
# [+] 0.4s
# Downloading  (5)  15%
# Extracting  (28)  ⣾  harminv                                             45.0kB @ 108.6kB/s  0.1s
# font-ttf-source-code-pro                           700.8kB @   1.6MB/s  0.0s
# font-ttf-ubuntu                                      1.6MB @   3.7MB/s  0.0s
# cached_property                                     11.1kB @  25.2kB/s  0.0s
# cached-property                                      4.1kB @   9.0kB/s  0.0s
# numpy                                                7.0MB @  15.1MB/s  0.1s
# [+] 0.5s
# Downloading  (5)  22%
# Extracting  (35)  ⣾  nettle                                               1.0MB @   1.9MB/s  0.1s
# x265                                                 3.4MB @   6.4MB/s  0.1s
# libdeflate                                          65.2kB @ 118.6kB/s  0.0s
# lerc                                               281.8kB @ 510.6kB/s  0.0s
# [+] 0.6s
# Downloading  (5)  25%
# Extracting  (39)  ⣾  libunistring                                         1.4MB @   2.4MB/s  0.1s
# openssl                                              2.9MB @   4.8MB/s  0.1s
# libbrotlidec                                        32.8kB @  51.8kB/s  0.0s
# libssh2                                            271.1kB @ 400.9kB/s  0.1s
# [+] 0.7s
# Downloading  (5)  34%
# Extracting  (40)  ⣾  p11-kit                                              4.7MB @   6.6MB/s  0.1s
# brotli-bin                                          19.0kB @  26.6kB/s  0.0s
# matplotlib-base                                      6.8MB @   9.4MB/s  0.3s
# pymeep-extras                                       13.8kB @  19.2kB/s  0.3s
# fontconfig                                         272.0kB @ 364.0kB/s  0.0s
# xorg-libxext                                        50.1kB @  67.1kB/s  0.0s
# xorg-libxfixes                                      18.1kB @  24.1kB/s  0.0s
# font-ttf-dejavu-sans-mono                          397.4kB @ 514.0kB/s  0.0s
# certifi                                            159.3kB @ 205.5kB/s  0.0s
# future                                             364.1kB @ 464.4kB/s  0.0s
# pymeep                                               1.7MB @   2.1MB/s  0.4s
# [+] 0.8s
# Downloading  (5)  37%
# Extracting  (52)  ⣾  autograd                                            45.0kB @  56.2kB/s  0.0s
# xorg-libx11                                        828.1kB @   1.0MB/s  0.1s
# fonttools                                            2.4MB @   2.9MB/s  0.1s
# libgdsii                                            86.7kB @ 103.7kB/s  0.1s
# xorg-libxau                                         14.5kB @  17.3kB/s  0.0s
# gmp                                                460.1kB @ 542.4kB/s  0.0s
# xorg-xextproto                                      30.3kB @  35.2kB/s  0.0s
# libwebp-base                                       439.0kB @ 508.3kB/s  0.0s
# libpciaccess                                        28.4kB @  32.8kB/s  0.0s
# libjpeg-turbo                                      496.4kB @ 566.2kB/s  0.0s
# libcblas                                            14.8kB @  16.6kB/s  0.0s
# [+] 0.9s
# Downloading  (5)  41%
# Extracting  (62)  ⣾  fftw                                                 2.1MB @   2.3MB/s  0.0s
# brotli                                              19.4kB @  21.5kB/s  0.0s
# libasprintf-devel                                   34.2kB @  37.9kB/s  0.1s
# pyparsing                                           89.5kB @  97.3kB/s  0.0s
# six                                                 14.3kB @  15.4kB/s  0.0s
# h5py                                                 1.2MB @   1.2MB/s  0.0s
# font-ttf-inconsolata                                96.5kB @ 101.4kB/s  0.1s
# unicodedata2                                       374.1kB @ 384.8kB/s  0.1s
# libtiff                                            416.5kB @ 422.1kB/s  0.0s
# [+] 1.0s
# Downloading  (5)  48%
# Extracting  (71)  ⣾  gettext-tools                                        2.7MB @   2.7MB/s  0.1s
# krb5                                                 1.4MB @   1.3MB/s  0.1s
# openjpeg                                           352.0kB @ 339.7kB/s  0.1s
# liblapack                                           14.8kB @  14.3kB/s  0.0s
# libasprintf                                         43.2kB @  41.1kB/s  0.1s
# packaging                                           50.3kB @  46.4kB/s  0.0s
# munkres                                             12.5kB @  11.5kB/s  0.0s
# python-dateutil                                    222.7kB @ 205.1kB/s  0.0s
# [+] 1.1s
# Downloading  (5)  54%
# Extracting  (80)  ⣾  scipy                                               16.7MB @  15.1MB/s  0.2s
# libopus                                            260.7kB @ 233.0kB/s  0.0s
# freetype                                           635.0kB @ 566.7kB/s  0.0s
# libdrm                                             305.5kB @ 272.3kB/s  0.0s
# libgfortran-ng                                      23.3kB @  20.4kB/s  0.1s
# fonts-conda-forge                                    4.1kB @   3.6kB/s  0.0s
# [+] 1.2s
# Downloading  (7)  60%
# Extracting  (86)  ⣾  libgfortran5                                         1.4MB @   1.2MB/s  0.2s
# kiwisolver                                          73.1kB @  61.1kB/s  0.2s
# libxcb                                             384.2kB @ 316.7kB/s  0.1s
# fonts-conda-ecosystem                                3.7kB @   3.0kB/s  0.1s
# [+] 1.3s
# Downloading  (8)  61%
# Extracting  (89)  ⣾  xorg-kbproto                                        27.3kB @  21.4kB/s  0.1s
# xorg-xproto                                         74.9kB @  58.7kB/s  0.1s
# libcurl                                            372.5kB @ 291.7kB/s  0.1s
# libaec                                              35.4kB @  27.1kB/s  0.1s
# libva                                              189.9kB @ 143.0kB/s  0.1s
# [+] 1.4s
# Downloading  (5)  68%
# Extracting  (94)  ⣾  lame                                               508.3kB @ 372.3kB/s  0.1s
# h5utils                                             69.6kB @  49.8kB/s  0.1s
# gsl                                                  3.4MB @   2.4MB/s  0.2s
# ffmpeg                                               9.6MB @   6.6MB/s  0.3s
# [+] 1.5s
# Downloading  (1)  76%
# Extracting  (98)  ⣾  [+] 1.6s
# Downloading  (1)  79%
# Extracting  (97)  ⣾  [+] 1.7s
# Downloading  (1)  88%
# Extracting  (97)  ⣾  [+] 1.8s
# Downloading  (1)  97%
# Extracting  (97)  ⣾  pillow                                              46.6MB @  25.5MB/s  0.6s
# [+] 1.9s
# Downloading      100%
# Extracting  (97)  ⣾  [+] 2.0s
# Downloading      100%
# Extracting  (96)  ⣾  [+] 2.1s
# Downloading      100%
# Extracting  (96)  ⣾  [+] 2.2s
# Downloading      100%
# Extracting  (96)  ⣾  [+] 2.3s
# Downloading      100%
# Extracting  (96)  ⣾  [+] 2.4s
# Downloading      100%
# Extracting  (96)  ⣾  [+] 2.5s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2.6s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2.7s
# Downloading      100%
# Extracting  (95)  ⣾  [+] 2.8s
# Downloading      100%
# Extracting  (94)  ⣾  [+] 2.9s
# Downloading      100%
# Extracting  (94)  ⣾  [+] 3.0s
# Downloading      100%
# Extracting  (94)  ⣾  [+] 3.1s
# Downloading      100%
# Extracting  (93)  ⣾  [+] 3.2s
# Downloading      100%
# Extracting  (93)  ⣾  [+] 3.3s
# Downloading      100%
# Extracting  (93)  ⣾  [+] 3.4s
# Downloading      100%
# Extracting  (92)  ⣾  [+] 3.5s
# Downloading      100%
# Extracting  (91)  ⣾  [+] 3.6s
# Downloading      100%
# Extracting  (91)  ⣾  [+] 3.7s
# Downloading      100%
# Extracting  (90)  ⣾  [+] 3.8s
# Downloading      100%
# Extracting  (90)  ⣾  [+] 3.9s
# Downloading      100%
# Extracting  (89)  ⣾  [+] 4.0s
# Downloading      100%
# Extracting  (89)  ⣾  [+] 4.1s
# Downloading      100%
# Extracting  (88)  ⣾  [+] 4.2s
# Downloading      100%
# Extracting  (87)  ⣾  [+] 4.3s
# Downloading      100%
# Extracting  (87)  ⣾  [+] 4.4s
# Downloading      100%
# Extracting  (87)  ⣾  [+] 4.5s
# Downloading      100%
# Extracting  (85)  ⣾  [+] 4.6s
# Downloading      100%
# Extracting  (85)  ⣾  [+] 4.7s
# Downloading      100%
# Extracting  (85)  ⣾  [+] 4.8s
# Downloading      100%
# Extracting  (83)  ⣾  [+] 4.9s
# Downloading      100%
# Extracting  (83)  ⣾  [+] 5.0s
# Downloading      100%
# Extracting  (83)  ⣾  [+] 5.1s
# Downloading      100%
# Extracting  (81)  ⣾  [+] 5.2s
# Downloading      100%
# Extracting  (81)  ⣾  [+] 5.3s
# Downloading      100%
# Extracting  (81)  ⣾  [+] 5.4s
# Downloading      100%
# Extracting  (81)  ⣾  [+] 5.5s
# Downloading      100%
# Extracting  (81)  ⣾  [+] 5.6s
# Downloading      100%
# Extracting  (80)  ⣾  [+] 5.7s
# Downloading      100%
# Extracting  (80)  ⣾  [+] 5.8s
# Downloading      100%
# Extracting  (79)  ⣾  [+] 5.9s
# Downloading      100%
# Extracting  (78)  ⣾  [+] 6.0s
# Downloading      100%
# Extracting  (78)  ⣾  [+] 6.1s
# Downloading      100%
# Extracting  (78)  ⣾  [+] 6.2s
# Downloading      100%
# Extracting  (77)  ⣾  [+] 6.3s
# Downloading      100%
# Extracting  (77)  ⣾  [+] 6.4s
# Downloading      100%
# Extracting  (77)  ⣾  [+] 6.5s
# Downloading      100%
# Extracting  (76)  ⣾  [+] 6.6s
# Downloading      100%
# Extracting  (76)  ⣾  [+] 6.7s
# Downloading      100%
# Extracting  (75)  ⣾  [+] 6.8s
# Downloading      100%
# Extracting  (75)  ⣾  [+] 6.9s
# Downloading      100%
# Extracting  (75)  ⣾  [+] 7.0s
# Downloading      100%
# Extracting  (74)  ⣾  [+] 7.1s
# Downloading      100%
# Extracting  (74)  ⣾  [+] 7.2s
# Downloading      100%
# Extracting  (74)  ⣾  [+] 7.3s
# Downloading      100%
# Extracting  (73)  ⣾  [+] 7.4s
# Downloading      100%
# Extracting  (73)  ⣾  [+] 7.5s
# Downloading      100%
# Extracting  (73)  ⣾  [+] 7.6s
# Downloading      100%
# Extracting  (72)  ⣾  [+] 7.7s
# Downloading      100%
# Extracting  (72)  ⣾  [+] 7.8s
# Downloading      100%
# Extracting  (72)  ⣾  [+] 7.9s
# Downloading      100%
# Extracting  (72)  ⣾  [+] 8.0s
# Downloading      100%
# Extracting  (71)  ⣾  [+] 8.1s
# Downloading      100%
# Extracting  (71)  ⣾  [+] 8.2s
# Downloading      100%
# Extracting  (70)  ⣾  [+] 8.3s
# Downloading      100%
# Extracting  (70)  ⣾  [+] 8.4s
# Downloading      100%
# Extracting  (70)  ⣾  [+] 8.5s
# Downloading      100%
# Extracting  (69)  ⣾  [+] 8.6s
# Downloading      100%
# Extracting  (69)  ⣾  [+] 8.7s
# Downloading      100%
# Extracting  (68)  ⣾  [+] 8.8s
# Downloading      100%
# Extracting  (68)  ⣾  [+] 8.9s
# Downloading      100%
# Extracting  (68)  ⣾  [+] 9.0s
# Downloading      100%
# Extracting  (68)  ⣾  [+] 9.1s
# Downloading      100%
# Extracting  (67)  ⣾  [+] 9.2s
# Downloading      100%
# Extracting  (67)  ⣾  [+] 9.3s
# Downloading      100%
# Extracting  (66)  ⣾  [+] 9.4s
# Downloading      100%
# Extracting  (66)  ⣾  [+] 9.5s
# Downloading      100%
# Extracting  (66)  ⣾  [+] 9.6s
# Downloading      100%
# Extracting  (65)  ⣾  [+] 9.7s
# Downloading      100%
# Extracting  (65)  ⣾  [+] 9.8s
# Downloading      100%
# Extracting  (64)  ⣾  [+] 9.9s
# Downloading      100%
# Extracting  (64)  ⣾  [+] 10.0s
# Downloading      100%
# Extracting  (64)  ⣾  [+] 10.1s
# Downloading      100%
# Extracting  (63)  ⣾  [+] 10.2s
# Downloading      100%
# Extracting  (62)  ⣾  [+] 10.3s
# Downloading      100%
# Extracting  (62)  ⣾  [+] 10.4s
# Downloading      100%
# Extracting  (62)  ⣾  [+] 10.5s
# Downloading      100%
# Extracting  (62)  ⣾  [+] 10.6s
# Downloading      100%
# Extracting  (62)  ⣾  [+] 10.7s
# Downloading      100%
# Extracting  (61)  ⣾  [+] 10.8s
# Downloading      100%
# Extracting  (61)  ⣾  [+] 10.9s
# Downloading      100%
# Extracting  (61)  ⣾  [+] 11.0s
# Downloading      100%
# Extracting  (60)  ⣾  [+] 11.1s
# Downloading      100%
# Extracting  (60)  ⣾  [+] 11.2s
# Downloading      100%
# Extracting  (60)  ⣾  [+] 11.3s
# Downloading      100%
# Extracting  (58)  ⣾  [+] 11.4s
# Downloading      100%
# Extracting  (58)  ⣾  [+] 11.5s
# Downloading      100%
# Extracting  (58)  ⣾  [+] 11.6s
# Downloading      100%
# Extracting  (57)  ⣾  [+] 11.7s
# Downloading      100%
# Extracting  (56)  ⣾  [+] 11.8s
# Downloading      100%
# Extracting  (56)  ⣾  [+] 11.9s
# Downloading      100%
# Extracting  (56)  ⣾  [+] 12.0s
# Downloading      100%
# Extracting  (55)  ⣾  [+] 12.1s
# Downloading      100%
# Extracting  (55)  ⣾  [+] 12.2s
# Downloading      100%
# Extracting  (54)  ⣾  [+] 12.3s
# Downloading      100%
# Extracting  (54)  ⣾  [+] 12.4s
# Downloading      100%
# Extracting  (54)  ⣾  [+] 12.5s
# Downloading      100%
# Extracting  (54)  ⣾  [+] 12.6s
# Downloading      100%
# Extracting  (54)  ⣾  [+] 12.7s
# Downloading      100%
# Extracting  (53)  ⣾  [+] 12.8s
# Downloading      100%
# Extracting  (52)  ⣾  [+] 12.9s
# Downloading      100%
# Extracting  (52)  ⣾  [+] 13.0s
# Downloading      100%
# Extracting  (52)  ⣾  [+] 13.1s
# Downloading      100%
# Extracting  (51)  ⣾  [+] 13.2s
# Downloading      100%
# Extracting  (51)  ⣾  [+] 13.3s
# Downloading      100%
# Extracting  (51)  ⣾  [+] 13.4s
# Downloading      100%
# Extracting  (50)  ⣾  [+] 13.5s
# Downloading      100%
# Extracting  (50)  ⣾  [+] 13.6s
# Downloading      100%
# Extracting  (50)  ⣾  [+] 13.7s
# Downloading      100%
# Extracting  (50)  ⣾  [+] 13.8s
# Downloading      100%
# Extracting  (49)  ⣾  [+] 13.9s
# Downloading      100%
# Extracting  (49)  ⣾  [+] 14.0s
# Downloading      100%
# Extracting  (49)  ⣾  [+] 14.1s
# Downloading      100%
# Extracting  (48)  ⣾  [+] 14.2s
# Downloading      100%
# Extracting  (47)  ⣾  [+] 14.3s
# Downloading      100%
# Extracting  (47)  ⣾  [+] 14.4s
# Downloading      100%
# Extracting  (46)  ⣾  [+] 14.5s
# Downloading      100%
# Extracting  (45)  ⣾  [+] 14.6s
# Downloading      100%
# Extracting  (45)  ⣾  [+] 14.7s
# Downloading      100%
# Extracting  (44)  ⣾  [+] 14.8s
# Downloading      100%
# Extracting  (43)  ⣾  [+] 14.9s
# Downloading      100%
# Extracting  (43)  ⣾  [+] 15.0s
# Downloading      100%
# Extracting  (42)  ⣾  [+] 15.1s
# Downloading      100%
# Extracting  (42)  ⣾  [+] 15.2s
# Downloading      100%
# Extracting  (41)  ⣾  [+] 15.3s
# Downloading      100%
# Extracting  (41)  ⣾  [+] 15.4s
# Downloading      100%
# Extracting  (40)  ⣾  [+] 15.5s
# Downloading      100%
# Extracting  (39)  ⣾  [+] 15.6s
# Downloading      100%
# Extracting  (39)  ⣾  [+] 15.7s
# Downloading      100%
# Extracting  (38)  ⣾  [+] 15.8s
# Downloading      100%
# Extracting  (37)  ⣾  [+] 15.9s
# Downloading      100%
# Extracting  (37)  ⣾  [+] 16.0s
# Downloading      100%
# Extracting  (37)  ⣾  [+] 16.1s
# Downloading      100%
# Extracting  (35)  ⣾  [+] 16.2s
# Downloading      100%
# Extracting  (35)  ⣾  [+] 16.3s
# Downloading      100%
# Extracting  (35)  ⣾  [+] 16.4s
# Downloading      100%
# Extracting  (34)  ⣾  [+] 16.5s
# Downloading      100%
# Extracting  (34)  ⣾  [+] 16.6s
# Downloading      100%
# Extracting  (33)  ⣾  [+] 16.7s
# Downloading      100%
# Extracting  (32)  ⣾  [+] 16.8s
# Downloading      100%
# Extracting  (32)  ⣾  [+] 16.9s
# Downloading      100%
# Extracting  (31)  ⣾  [+] 17.0s
# Downloading      100%
# Extracting  (30)  ⣾  [+] 17.1s
# Downloading      100%
# Extracting  (30)  ⣾  [+] 17.2s
# Downloading      100%
# Extracting  (29)  ⣾  [+] 17.3s
# Downloading      100%
# Extracting  (28)  ⣾  [+] 17.4s
# Downloading      100%
# Extracting  (28)  ⣾  [+] 17.5s
# Downloading      100%
# Extracting  (27)  ⣾  [+] 17.6s
# Downloading      100%
# Extracting  (26)  ⣾  [+] 17.7s
# Downloading      100%
# Extracting  (26)  ⣾  [+] 17.8s
# Downloading      100%
# Extracting  (26)  ⣾  [+] 17.9s
# Downloading      100%
# Extracting  (25)  ⣾  [+] 18.0s
# Downloading      100%
# Extracting  (25)  ⣾  [+] 18.1s
# Downloading      100%
# Extracting  (25)  ⣾  [+] 18.2s
# Downloading      100%
# Extracting  (25)  ⣾  [+] 18.3s
# Downloading      100%
# Extracting  (24)  ⣾  [+] 18.4s
# Downloading      100%
# Extracting  (23)  ⣾  [+] 18.5s
# Downloading      100%
# Extracting  (23)  ⣾  [+] 18.6s
# Downloading      100%
# Extracting  (23)  ⣾  [+] 18.7s
# Downloading      100%
# Extracting  (22)  ⣾  [+] 18.8s
# Downloading      100%
# Extracting  (22)  ⣾  [+] 18.9s
# Downloading      100%
# Extracting  (22)  ⣾  [+] 19.0s
# Downloading      100%
# Extracting  (22)  ⣾  [+] 19.1s
# Downloading      100%
# Extracting  (22)  ⣾  [+] 19.2s
# Downloading      100%
# Extracting  (22)  ⣾  [+] 19.3s
# Downloading      100%
# Extracting  (21)  ⣾  [+] 19.4s
# Downloading      100%
# Extracting  (20)  ⣾  [+] 19.5s
# Downloading      100%
# Extracting  (20)  ⣾  [+] 19.6s
# Downloading      100%
# Extracting  (19)  ⣾  [+] 19.7s
# Downloading      100%
# Extracting  (18)  ⣾  [+] 19.8s
# Downloading      100%
# Extracting  (18)  ⣾  [+] 19.9s
# Downloading      100%
# Extracting  (17)  ⣾  [+] 20.0s
# Downloading      100%
# Extracting  (17)  ⣾  [+] 20.1s
# Downloading      100%
# Extracting  (17)  ⣾  [+] 20.2s
# Downloading      100%
# Extracting  (17)  ⣾  [+] 20.3s
# Downloading      100%
# Extracting  (16)  ⣾  [+] 20.4s
# Downloading      100%
# Extracting  (16)  ⣾  [+] 20.5s
# Downloading      100%
# Extracting  (16)  ⣾  [+] 20.6s
# Downloading      100%
# Extracting  (15)  ⣾  [+] 20.7s
# Downloading      100%
# Extracting  (15)  ⣾  [+] 20.8s
# Downloading      100%
# Extracting  (15)  ⣾  [+] 20.9s
# Downloading      100%
# Extracting  (15)  ⣾  [+] 21.0s
# Downloading      100%
# Extracting  (13)  ⣾  [+] 21.1s
# Downloading      100%
# Extracting  (13)  ⣾  [+] 21.2s
# Downloading      100%
# Extracting  (13)  ⣾  [+] 21.3s
# Downloading      100%
# Extracting  (13)  ⣾  [+] 21.4s
# Downloading      100%
# Extracting  (13)  ⣾  [+] 21.5s
# Downloading      100%
# Extracting  (13)  ⣾  [+] 21.6s
# Downloading      100%
# Extracting  (12)  ⣾  [+] 21.7s
# Downloading      100%
# Extracting  (12)  ⣾  [+] 21.8s
# Downloading      100%
# Extracting  (11)  ⣾  [+] 21.9s
# Downloading      100%
# Extracting  (11)  ⣾  [+] 22.0s
# Downloading      100%
# Extracting  (11)  ⣾  [+] 22.1s
# Downloading      100%
# Extracting  (11)  ⣾  [+] 22.2s
# Downloading      100%
# Extracting  (11)  ⣾  [+] 22.3s
# Downloading      100%
# Extracting  (11)  ⣾  [+] 22.4s
# Downloading      100%
# Extracting   (9)  ⣾  [+] 22.5s
# Downloading      100%
# Extracting   (9)  ⣾  [+] 22.6s
# Downloading      100%
# Extracting   (9)  ⣾  [+] 22.7s
# Downloading      100%
# Extracting   (9)  ⣾  [+] 22.8s
# Downloading      100%
# Extracting   (9)  ⣾  [+] 22.9s
# Downloading      100%
# Extracting   (8)  ⣾  [+] 23.0s
# Downloading      100%
# Extracting   (7)  ⣾  [+] 23.1s
# Downloading      100%
# Extracting   (7)  ⣾  [+] 23.2s
# Downloading      100%
# Extracting   (7)  ⣾  [+] 23.3s
# Downloading      100%
# Extracting   (7)  ⣾  [+] 23.4s
# Downloading      100%
# Extracting   (6)  ⣾  [+] 23.5s
# Downloading      100%
# Extracting   (6)  ⣾  [+] 23.6s
# Downloading      100%
# Extracting   (6)  ⣾  [+] 23.7s
# Downloading      100%
# Extracting   (6)  ⣾  [+] 23.8s
# Downloading      100%
# Extracting   (6)  ⣾  [+] 23.9s
# Downloading      100%
# Extracting   (6)  ⣾  [+] 24.0s
# Downloading      100%
# Extracting   (5)  ⣾  [+] 24.1s
# Downloading      100%
# Extracting   (5)  ⣾  [+] 24.2s
# Downloading      100%
# Extracting   (5)  ⣾  [+] 24.3s
# Downloading      100%
# Extracting   (5)  ⣾  [+] 24.4s
# Downloading      100%
# Extracting   (5)  ⣾  [+] 24.5s
# Downloading      100%
# Extracting   (5)  ⣾  [+] 24.6s
# Downloading      100%
# Extracting   (4)  ⣾  [+] 24.7s
# Downloading      100%
# Extracting   (4)  ⣾  [+] 24.8s
# Downloading      100%
# Extracting   (4)  ⣾  [+] 24.9s
# Downloading      100%
# Extracting   (4)  ⣾  [+] 25.0s
# Downloading      100%
# Extracting   (3)  ⣾  [+] 25.1s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 25.2s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 25.3s
# Downloading      100%
# Extracting   (2)  ⣾  [+] 25.4s
# Downloading      100%
# Extracting   (1)  ⣾
# Downloading and Extracting Packages
#
# done
# done
# done

# %%
# check version meep

import meep as mp
mp.__version__
# Out:
# '1.29.0'

# %%
# install other

# !pip install nlopt
# Out:
# Collecting nlopt
#   Downloading nlopt-2.7.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (423 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 423.7/423.7 kB 7.0 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.14 in /usr/local/lib/python3.10/site-packages (from nlopt) (1.26.4)
# Installing collected packages: nlopt
# Successfully installed nlopt-2.7.1

# %% [markdown]
# # import n k

# %%
import pandas as pd
from google.colab import drive

# This will prompt for authorization.
drive.mount('/content/drive')

# After executing the cell above, Drive
# files will be present in "/content/drive/My Drive".
# If the file is in a folder, the path will look like:
# '/content/drive/My Drive/folder/your_file.csv'

dataNK = pd.read_csv('/content/drive/MyDrive/nk-data/n_k data.csv')
dataNK
# Out:
# Mounted at /content/drive
#      Wavelength (nm)  Air_n  Air_k  Spiro_n  Spiro_k   TiO2_n   TiO2_k  \
# 0                301      1      0  1.61701  0.25452  2.67767  0.62089
# 1                302      1      0  1.62022  0.25795  2.68572  0.60651
# 2                303      1      0  1.62360  0.26089  2.69355  0.59251
# 3                304      1      0  1.62709  0.26335  2.70112  0.57898
# 4                305      1      0  1.63072  0.26535  2.70854  0.56568
# ..               ...    ...    ...      ...      ...      ...      ...
# 594              895      1      0  1.67604  0.00379  2.04614  0.00000
# 595              896      1      0  1.67627  0.00428  2.04601  0.00000
# 596              897      1      0  1.67650  0.00482  2.04587  0.00000
# 597              898      1      0  1.67673  0.00542  2.04574  0.00000
# 598              899      1      0  1.67695  0.00608  2.04561  0.00000
#
#      SodaLime_n  SodaLime_k  Perov_n  ...  FTema_n  FTema_k  FAema_n  FAema_k  \
# 0       1.54873    0.000059  1.48952  ...  2.27183  0.16484  1.74080  0.02115
# 1       1.54837    0.000056  1.48478  ...  2.26866  0.16262  1.73865  0.02030
# 2       1.54800    0.000053  1.48040  ...  2.26555  0.16046  1.73658  0.01951
# 3       1.54764    0.000051  1.47642  ...  2.26253  0.15839  1.73453  0.01878
# 4       1.54727    0.000048  1.47298  ...  2.25949  0.15632  1.73256  0.01807
# ..          ...         ...      ...  ...      ...      ...      ...      ...
# 594     1.50200    0.000004  2.42143  ...  1.77954  0.01303  1.43703  0.01240
# 595     1.50193    0.000004  2.42093  ...  1.77886  0.01308  1.43659  0.01245
# 596     1.50190    0.000004  2.42042  ...  1.77823  0.01312  1.43612  0.01249
# 597     1.50190    0.000004  2.41993  ...  1.77761  0.01317  1.43572  0.01253
# 598     1.50190    0.000004  2.41942  ...  1.77698  0.01322  1.43527  0.01258
#
#      TPema_n  TPema_k  SpiroTFSI4Ox_n  SpiroTFSI4Ox_k  SpOxema_n  SpOxema_k
# 0    2.24501  0.70247         1.64180        0.251950       1.62    0.25400
# 1    2.24828  0.69505         1.64526        0.254320       1.62    0.25800
# 2    2.25154  0.68812         1.64898        0.256190       1.63    0.26000
# 3    2.25478  0.68169         1.65279        0.257480       1.63    0.26300
# 4    2.25814  0.67567         1.65663        0.258730       1.63    0.26500
# ..       ...      ...             ...             ...        ...        ...
# 594  2.17520  0.04419         1.67284        0.000561       1.68    0.00347
# 595  2.17494  0.04410         1.67237        0.000537       1.68    0.00391
# 596  2.17467  0.04400         1.67246        0.000606       1.68    0.00440
# 597  2.17442  0.04391         1.67331        0.000338       1.68    0.00491
# 598  2.17416  0.04382         1.67286        0.000299       1.68    0.00550
#
# [599 rows x 31 columns]

# %%
print(dataNK.columns)
# Out:
# Index(['Wavelength (nm)', 'Air_n', 'Air_k', 'Spiro_n', 'Spiro_k', 'TiO2_n',
#        'TiO2_k', 'SodaLime_n', 'SodaLime_k', 'Perov_n', 'Perov_k',
#        'PerovPtPt_n', 'PerovPtPt_k', 'Au_n', 'Au_k', 'SnO2_n', 'SnO2_k',
#        'SiO2_n', 'SiO2_k', 'FTO_n', 'FTO_k', 'FTema_n', 'FTema_k', 'FAema_n',
#        'FAema_k', 'TPema_n', 'TPema_k', 'SpiroTFSI4Ox_n', 'SpiroTFSI4Ox_k',
#        'SpOxema_n', 'SpOxema_k'],
#       dtype='object')

# %% [markdown]
# # init data

# %%
import meep as mp
import numpy as np
from typing import List

# set data for wavelengt and n k materials
wavelengths = dataNK["Wavelength (nm)"]
wavelengthsUm = [i / 1000 for i in wavelengths]
freqs = [1000 / (i) for i in wavelengths]
auN = dataNK["Au_n"]
auK = dataNK["Au_k"]
spiroN = dataNK["Spiro_n"]
spiroK = dataNK["Spiro_k"]
perovN = dataNK["Perov_n"]
perovK = dataNK["Perov_k"]
tio2N = dataNK["TiO2_n"]
tio2K = dataNK["TiO2_k"]

# Define the dimensions of the simulation
# 1um = 1000 nm
auHeight = 0.1  # 0.1 um or 100 nm
spiroHeight = 0.2  # 0.2 um or 200 nm
perovHeight = 0.37  # 0.37 um or 370 nm
tio2Height = 0.07  # 0.07 um or 70 nm
xLength = 1  # 1 um or 1000 nm
yLength = 1  # 1 um or 1000 nm
cellHeight = auHeight + spiroHeight + perovHeight + tio2Height
cellLength = 1
cellWidth = 1
cellSim = mp.Vector3(16, 8 + 0.5)
nmtoum = 1000

# %%
"""
A module for fitting the complex refractive index profile over a broad
bandwidth to a sum of Lorentzian polarizability terms using gradient-based
optimization via NLopt (nlopt.readthedocs.io). The fitting parameters are
then used to define a `Medium` object.
"""

from typing import Tuple
import csv
import matplotlib
import meep as mp
import nlopt
import numpy as np
import matplotlib.pyplot as plt

def lorentzfunc(p: np.ndarray, x: np.ndarray) -> np.ndarray:
    """
    Returns the complex ε profile given a set of Lorentzian parameters p
    (σ_0, ω_0, γ_0, σ_1, ω_1, γ_1, ...) for a set of frequencies x.
    """
    N = len(p) // 3
    y = np.zeros(len(x))
    for n in range(N):
        A_n = p[3 * n + 0]
        x_n = p[3 * n + 1]
        g_n = p[3 * n + 2]
        y = y + A_n / (np.square(x_n) - np.square(x) - 1j * x * g_n)
    return y


def lorentzerr(p: np.ndarray, x: np.ndarray, y: np.ndarray, grad: np.ndarray) -> float:
    """
    Returns the error (or residual or loss) as the L2 norm
    of the difference of ε(p,x) and y over a set of frequencies x as
    well as the gradient of this error with respect to each Lorentzian
    polarizability parameter in p and saving the result in grad.
    """
    N = len(p) // 3
    yp = lorentzfunc(p, x)
    val = np.sum(np.square(abs(y - yp)))
    for n in range(N):
        A_n = p[3 * n + 0]
        x_n = p[3 * n + 1]
        g_n = p[3 * n + 2]
        d = 1 / (np.square(x_n) - np.square(x) - 1j * x * g_n)
        if grad.size > 0:
            grad[3 * n + 0] = 2 * np.real(np.dot(np.conj(yp - y), d))
            grad[3 * n + 1] = (
                -4 * x_n * A_n * np.real(np.dot(np.conj(yp - y), np.square(d)))
            )
            grad[3 * n + 2] = (
                -2 * A_n * np.imag(np.dot(np.conj(yp - y), x * np.square(d)))
            )
    return val


def lorentzfit(
    p0: np.ndarray,
    x: np.ndarray,
    y: np.ndarray,
    alg=nlopt.LD_LBFGS,
    tol: float = 1e-25,
    maxeval: float = 10000,
) -> Tuple[np.ndarray, float]:
    """
    Returns the optimal Lorentzian polarizability parameters and error
    which minimize the error in ε(p0,x) relative to y for an initial
    set of Lorentzian polarizability parameters p0 over a set of
    frequencies x using the NLopt algorithm alg for a relative
    tolerance tol and a maximum number of iterations maxeval.
    """
    opt = nlopt.opt(alg, len(p0))
    opt.set_ftol_rel(tol)
    opt.set_maxeval(maxeval)
    opt.set_lower_bounds(np.zeros(len(p0)))
    opt.set_upper_bounds(float("inf") * np.ones(len(p0)))
    opt.set_min_objective(lambda p, grad: lorentzerr(p, x, y, grad))
    local_opt = nlopt.opt(nlopt.LD_LBFGS, len(p0))
    local_opt.set_ftol_rel(1e-10)
    local_opt.set_xtol_rel(1e-8)
    opt.set_local_optimizer(local_opt)
    popt = opt.optimize(p0)
    minf = opt.last_optimum_value()
    return popt, minf

# Import the complex refractive index profile from a CSV file.
# The file format is three comma-separated columns:
#     wavelength (nm), real(n), imag(n).
# Fitting parameter: number of Lorentzian terms to use in the fit
# Number of times to repeat local optimization with random initial values.
def fit_material_properties(wavelength, nArray, kArray, num_lorentzians, num_repeat, fileNameDest):
    mydata = np.column_stack((wavelength, nArray, kArray))
    n = mydata[:, 1] + 1j * mydata[:, 2]

    # Fitting parameter: the instantaneous (infinite frequency) dielectric.
    # Should be > 1.0 for stability and chosen such that
    # np.amin(np.real(eps)) is ~1.0. eps is defined below.
    eps_inf = 1.1
    eps = np.square(n) - eps_inf

    wl = mydata[:, 0]
    # wl_min = 399
    # wl_max = 701
    # start_idx = np.where(wl > wl_min)[0][0]
    # end_idx = np.where(wl < wl_max)[0][-1] + 1

    # The fitting function is ε(f) where f is the frequency, rather than ε(λ).
    # Note: an equally spaced grid of wavelengths results in the larger
    #       wavelengths having a finer frequency grid than smaller ones.
    #       This feature may impact the accuracy of the fit.
    freqs = 1000 / wl
    freqs_reduced = freqs
    eps_reduced = eps

    # Fitting parameter: number of Lorentzian terms to use in the fit
    num_lorentzians = num_lorentzians

    # Number of times to repeat local optimization with random initial values.
    num_repeat = num_repeat

    ps = np.zeros((num_repeat, 3 * num_lorentzians))
    mins = np.zeros(num_repeat)
    for m in range(num_repeat):
        # Initial values for the Lorentzian polarizability terms. Each term
        # consists of three parameters (σ, ω, γ) and is chosen randomly.
        # Note: for the case of no absorption, γ should be set to zero.
        p_rand = [10 ** (np.random.random()) for _ in range(3 * num_lorentzians)]
        ps[m, :], mins[m] = lorentzfit(
            p_rand, freqs_reduced, eps_reduced, nlopt.LD_MMA, 1e-25, 50000
        )
        ps_str = "( " + ", ".join(f"{prm:.4f}" for prm in ps[m, :]) + " )"
        print(f"iteration:, {m:3d}, ps_str, {mins[m]:.6f}")

    # Find the best performing set of parameters.
    idx_opt = np.where(np.min(mins) == mins)[0][0]
    popt_str = "( " + ", ".join(f"{prm:.4f}" for prm in ps[idx_opt]) + " )"
    print(f"optimal:, {popt_str}, {mins[idx_opt]:.6f}")

    # Define a `Medium` class object using the optimal fitting parameters.
    E_susceptibilities = []
    fileNameDest = fileNameDest + ".csv"
    with open(fileNameDest, mode='w', newline='') as file:
      writer = csv.writer(file)
      # Write the header row
      writer.writerow(['mymaterial_freq', 'mymaterial_gamma', 'mymaterial_sigma'])

      for n in range(num_lorentzians):
        mymaterial_freq = ps[idx_opt][3 * n + 1]
        mymaterial_gamma = ps[idx_opt][3 * n + 2]

        if mymaterial_freq == 0:
            mymaterial_sigma = ps[idx_opt][3 * n + 0]
            E_susceptibilities.append(
                mp.DrudeSusceptibility(
                    frequency=1.0, gamma=mymaterial_gamma, sigma=mymaterial_sigma
                )
            )
        else:
            mymaterial_sigma = ps[idx_opt][3 * n + 0] / mymaterial_freq**2
            E_susceptibilities.append(
                mp.LorentzianSusceptibility(
                    frequency=mymaterial_freq,
                    gamma=mymaterial_gamma,
                    sigma=mymaterial_sigma,
                )
            )
        # Write the values to the CSV file
        writer.writerow([mymaterial_freq, mymaterial_gamma, mymaterial_sigma])

    return E_susceptibilities

# func to plot epsilon actual
def plotEps(wavelength, nArray, kArray, epsInf):
    eps = [complex(nArray[i], kArray[i]) ** 2 for i in range(len(kArray))]
    eps = [e - epsInf for e in eps]
    plt.scatter(wavelength, [i.real for i in eps], label="Real", s=0.5)
    plt.scatter(wavelength, [i.imag for i in eps], label="Imaginary", s=0.5)
    plt.xlabel("Wavelength (nm)")
    plt.ylabel("Epsilon")
    plt.legend()
    plt.show()

# func to plot comparasion epsilon actual with fit
def plotEpsComp(wavelength, nArray, kArray, epsReal, epsImag):
    eps = [complex(nArray[i], kArray[i]) ** 2 for i in range(len(kArray))]
    plt.scatter(wavelength, [i.real for i in eps], label="Real actual", s=0.5)
    plt.scatter(wavelength, epsReal, label="Real fit", s=0.5)
    plt.scatter(wavelength, [i.imag for i in eps], label="Imaginary actual", s=0.5)
    plt.scatter(wavelength, epsImag, label="Imaginary fit", s=0.5)
    plt.xlabel("Wavelength (nm)")
    plt.ylabel("Epsilon")
    plt.legend()
    plt.show()

# %%
eps_inf = 1.1
plotEps(wavelengths, perovN, perovK, eps_inf)

# %% [markdown]
# # susceptibilities perov

# %%
# perovEscp = fit_material_properties(wavelengths, perovN, perovK, 10, 25, "perovEscp")

# print(perovEscp)
# perovMat = mp.Medium(epsilon=eps_inf, E_susceptibilities=perovEscp)
# pervMatEps = [perovMat.epsilon(f)[0][0] for f in freqs]

# print(pervMatEps)
# plotEpsComp(wavelengths, perovN, perovK, np.real(pervMatEps), np.imag(pervMatEps))

# %%
import csv
import meep as mp

def read_material_parameters_from_csv(filename='material_parameters.csv'):
    E_susceptibilities = []

    with open(filename, mode='r', newline='') as file:
        reader = csv.reader(file)
        next(reader)  # Skip the header row

        for row in reader:
            mymaterial_freq = float(row[0])
            mymaterial_gamma = float(row[1])
            mymaterial_sigma = float(row[2])

            if mymaterial_freq == 0:
                susceptibility = mp.DrudeSusceptibility(
                    frequency=1.0, gamma=mymaterial_gamma, sigma=mymaterial_sigma
                )
            else:
                susceptibility = mp.LorentzianSusceptibility(
                    frequency=mymaterial_freq,
                    gamma=mymaterial_gamma,
                    sigma=mymaterial_sigma,
                )
            E_susceptibilities.append(susceptibility)

    return E_susceptibilities

# %%
perovEscp = read_material_parameters_from_csv("/content/drive/MyDrive/nk-data/perovEscp.csv")
perovMat = mp.Medium(epsilon=eps_inf, E_susceptibilities=perovEscp)
pervMatEps = [perovMat.epsilon(f)[0][0] for f in freqs]
plotEpsComp(wavelengths, perovN, perovK, np.real(pervMatEps), np.imag(pervMatEps))

# %% [markdown]
# # run simulation basic

# %%
cell = mp.Vector3(16,8,0)

geometry = [mp.Block(mp.Vector3(mp.inf,1,mp.inf),
                     center=mp.Vector3(),
                     material=mp.Medium(epsilon=12))]

sources = [mp.Source(mp.ContinuousSource(frequency=0.15),
                     component=mp.Ez,
                     center=mp.Vector3(-7,0))]

pml_layers = [mp.PML(1.0)]

resolution = 10

sim = mp.Simulation(cell_size=cell,
                    boundary_layers=pml_layers,
                    geometry=geometry,
                    sources=sources,
                    resolution=resolution)

sim.run(until=200)
# Out:
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000265121 s
# Working in 2D dimensions.
# Computational cell is 16 x 8 x 0 with resolution 10
#      block, center = (0,0,0)
#           size (1e+20,1,1e+20)
#           axes (1,0,0), (0,1,0), (0,0,1)
#           dielectric constant epsilon diagonal = (12,12,12)
# time for set_epsilon = 0.034518 s
# -----------
# FloatProgress(value=0.0, description='0% done ', max=200.0)
# run 0 finished at t = 200.0 (4000 timesteps)

# %%
eps_data = sim.get_array(center=mp.Vector3(), size=cell, component=mp.Dielectric)
plt.figure()
plt.imshow(eps_data.transpose(), interpolation='spline36', cmap='binary')
plt.axis('off')
plt.show()

# %%
ez_data = sim.get_array(center=mp.Vector3(), size=cell, component=mp.Ez)
plt.figure()
plt.imshow(eps_data.transpose(), interpolation='spline36', cmap='binary')
plt.imshow(ez_data.transpose(), interpolation='spline36', cmap='RdBu', alpha=0.9)
plt.axis('off')
plt.show()

# %% [markdown]
# # test simulation E_suscepbility

# %%
import numpy as np
import math
import matplotlib.pyplot as plt


resolution = 200  # pixels/μm

dpml = 1.0
sz = 10 + 2 * dpml
cell_size = mp.Vector3(z=sz)
pml_layers = [mp.PML(dpml)]

wvl_min = 0.4
wvl_max = 0.8
fmin = 1 / wvl_max
fmax = 1 / wvl_min
fcen = 0.5 * (fmax + fmin)
df = fmax - fmin
nfreq = 50

sources = [
    mp.Source(
        mp.GaussianSource(fcen, fwidth=df),
        component=mp.Ex,
        center=mp.Vector3(z=-0.5 * sz + dpml),
    )
]

sim = mp.Simulation(
    cell_size=cell_size,
    boundary_layers=pml_layers,
    sources=sources,
    dimensions=1,
    resolution=resolution,
)

refl_fr = mp.FluxRegion(center=mp.Vector3(z=-0.25 * sz))
refl = sim.add_flux(fcen, df, nfreq, refl_fr)

sim.run(until_after_sources=mp.stop_when_fields_decayed(50, mp.Ex, mp.Vector3(), 1e-9))

empty_flux = mp.get_fluxes(refl)
empty_data = sim.get_flux_data(refl)
sim.reset_meep()

geometry = [
    mp.Block(
        mp.Vector3(mp.inf, mp.inf, 0.5 * sz),
        center=mp.Vector3(z=0.25 * sz),
        material=perovMat,
    )
]

sim = mp.Simulation(
    cell_size=cell_size,
    boundary_layers=pml_layers,
    geometry=geometry,
    sources=sources,
    dimensions=1,
    resolution=resolution,
)

refl = sim.add_flux(fcen, df, nfreq, refl_fr)
sim.load_minus_flux_data(refl, empty_data)

sim.run(until_after_sources=mp.stop_when_fields_decayed(50, mp.Ex, mp.Vector3(), 1e-9))

refl_flux = mp.get_fluxes(refl)
R_meep = -1 * np.divide(refl_flux, empty_flux)
# Out:
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000212908 s
# Working in 1D dimensions.
# Computational cell is 0 x 0 x 12 with resolution 200
# time for set_epsilon = 0.0013659 s
# -----------
# field decay(t = 50.0025): 0.2501893277392139 / 0.2501893277392139 = 1.0
# field decay(t = 100.0025): 4.3583172700896866e-16 / 0.2501893277392139 = 1.7420076665430753e-15
# run 0 finished at t = 100.0025 (40001 timesteps)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-cfdac4d11675> in <cell line: 47>()
#      48         mp.Vector3(mp.inf, mp.inf, 0.5 * sz),
#      49         center=mp.Vector3(z=0.25 * sz),
# ---> 50         material=perovMat,
#      51     )
#      52 ]
#
# NameError: name 'perovMat' is not defined

# %%
print(R_meep)
# Out:
# [0.18613425 0.18856062 0.19108588 0.19345778 0.19505489 0.19487707
#  0.192544   0.18960307 0.18801273 0.18813719 0.18940226 0.19125913
#  0.19338837 0.19562773 0.19789561 0.20014652 0.20235024 0.20448158
#  0.20651513 0.2084228  0.21017337 0.21173229 0.2130622  0.21412481
#  0.214883   0.21530359 0.21536092 0.21504079 0.21434384 0.21328873
#  0.21191376 0.21027688 0.20845359 0.20653302 0.2046122  0.20278866
#  0.2011542  0.19978852 0.19875442 0.19809518 0.19783387 0.19797375
#  0.19850011 0.19938315 0.20058044 0.20203973 0.20370206 0.20550391
#  0.20738288 0.20927418]

# %%
freqs = mp.get_flux_freqs(refl)
wvls = np.divide(1, freqs)

plt.figure()
plt.plot(wvls, R_meep, "bo-", label="meep")
plt.xlabel("wavelength (μm)")
plt.ylabel("reflectance")
plt.legend(loc="upper right")
plt.show()

# %% [markdown]
# # try bend flux

# %%
import numpy as np
import matplotlib.pyplot as plt

import meep as mp
from meep.materials import SiO2

resolution = 100  # pixels/um

dpml = 1.0
pml_layers = [mp.PML(thickness=dpml)]

r = 1.0  # radius of cylinder
dair = 2.0  # air padding thickness

s = 2 * (dpml + dair + r)
cell_size = mp.Vector3(s, s)

wvl_min = 0.4
wvl_max = 0.8
fmin = 1 / wvl_max
fmax = 1 / wvl_min
fcen = 0.5 * (fmax + fmin) # pulse center frequency
df = fmax - fmin # pulse width (in frequency)
nfreq = int((fcen + df/2) - (fcen - df/2))
nfreq = 100
print("fcen", fcen)
print("df", df)
print("nfreq", nfreq)

# is_integrated=True necessary for any planewave source extending into PML
sources = [
    mp.Source(
        mp.GaussianSource(fcen, fwidth=df, is_integrated=False),
        center=mp.Vector3(-0.5 * s + dpml),
        size=mp.Vector3(0, s),
        component=mp.Ez,
    )
]

sim = mp.Simulation(
    cell_size=cell_size,
    boundary_layers=pml_layers,
    sources=sources,
    resolution=resolution,
)

refl_fr = mp.FluxRegion(
    center=mp.Vector3(-r), size=mp.Vector3(0, s)
)


refl = sim.add_flux(fcen, df, nfreq, refl_fr)
print("refl pos", refl_fr.center)
print("refl size", refl_fr.size)

tran_fr = mp.FluxRegion(
    center=mp.Vector3(r), size=mp.Vector3(0, s)
)
tran = sim.add_flux(fcen, df, nfreq, tran_fr)
print("tran pos", tran_fr.center)
print("tran size", tran_fr.size)

plt.figure(dpi=150)
sim.plot2D()
plt.show()
# Out:
# fcen 1.875
# df 1.25
# nfreq 100
# refl pos Vector3<-1.0, 0.0, 0.0>
# refl size Vector3<0.0, 8.0, 0.0>
# tran pos Vector3<1.0, 0.0, 0.0>
# tran size Vector3<0.0, 8.0, 0.0>

# %%
sim.run(until_after_sources=mp.stop_when_fields_decayed(5, mp.Ez, mp.Vector3(0,0), 1e-9))
# Out:
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.00106478 s
# Working in 2D dimensions.
# Computational cell is 8 x 8 x 0 with resolution 100
# time for set_epsilon = 1.60188 s
# -----------
# on time step 550 (time=2.75), 0.00727576 s/step
# field decay(t = 5.005): 0.0002718901764637685 / 0.0002718901764637685 = 1.0
# on time step 1170 (time=5.85), 0.00645552 s/step
# on time step 1791 (time=8.955), 0.00645274 s/step
# field decay(t = 10.01): 0.24734102309236122 / 0.24734102309236122 = 1.0
# on time step 2256 (time=11.28), 0.00861815 s/step
# on time step 2927 (time=14.635), 0.00597011 s/step
# field decay(t = 15.015): 1.8366527088553444e-05 / 0.24734102309236122 = 7.425588711054648e-05
# on time step 3631 (time=18.155), 0.00568392 s/step
# field decay(t = 20.02): 6.037190865106984e-15 / 0.24734102309236122 = 2.4408368614423486e-14
# run 0 finished at t = 20.02 (4004 timesteps)

# %%
empty_flux = mp.get_fluxes(refl)
empty_data = sim.get_flux_data(refl)
sim.reset_meep()

# %%
symmetries = [mp.Mirror(mp.Y)]

geometry = [mp.Cylinder(material=perovMat, center=mp.Vector3(), radius=r, height=mp.inf)]

sim = mp.Simulation(
    resolution=resolution,
    cell_size=cell_size,
    boundary_layers=pml_layers,
    sources=sources,
    k_point=mp.Vector3(),
    symmetries=symmetries,
    geometry=geometry,
)

refl = sim.add_flux(fcen, df, nfreq, refl_fr)

plt.figure(dpi=150)
sim.plot2D()
plt.show()
# Out:
#      cylinder, center = (0,0,0)
#           radius 1, height 1e+20, axis (0, 0, 1)
#           dielectric constant epsilon diagonal = (1.1,1.1,1.1)

# %%
sim.load_minus_flux_data(refl, empty_data)

sim.run(until_after_sources=mp.stop_when_fields_decayed(50, mp.Ex, mp.Vector3(), 1e-9))

refl_flux = mp.get_fluxes(refl)
R_meep = -1*np.divide(refl_flux,empty_flux)
# Out:
# -----------
# Initializing structure...
# Halving computational cell along direction y
# time for choose_chunkdivision = 0.00540709 s
# Working in 2D dimensions.
# Computational cell is 8 x 8 x 0 with resolution 100
#      cylinder, center = (0,0,0)
#           radius 1, height 1e+20, axis (0, 0, 1)
#           dielectric constant epsilon diagonal = (1.1,1.1,1.1)
# time for set_epsilon = 0.921821 s
# lorentzian susceptibility: frequency=2.65066, gamma=0.819314
# lorentzian susceptibility: frequency=2.00388, gamma=0.807751
# lorentzian susceptibility: frequency=10.1218, gamma=0
# lorentzian susceptibility: frequency=6.41527, gamma=0
# lorentzian susceptibility: frequency=1.3978, gamma=0.167977
# lorentzian susceptibility: frequency=3.42329, gamma=0.459484
# lorentzian susceptibility: frequency=7.68042, gamma=0
# lorentzian susceptibility: frequency=10.1572, gamma=0
# lorentzian susceptibility: frequency=2.90996, gamma=0.626243
# lorentzian susceptibility: frequency=7.28411, gamma=0
# -----------
